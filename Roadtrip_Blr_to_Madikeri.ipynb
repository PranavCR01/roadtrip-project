# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Planning a Cool Weekend Trip from Bangalore Using Data

# %% [markdown]
# ## Setup and Dependencies

# %%
# Coordinates for Bangalore, India
origin_lat = 12.9716
origin_lon = 77.5946

# Target radius: 300 km driving distance
max_radius_km = 300

# Number of candidate locations to generate
num_points = 1000

# Approximate expected temperature in Bangalore
bangalore_temp_reference = 33.0  # degrees Celsius


# Standard dependencies
import math
import time
import folium
import spotipy
import requests
import polyline
import numpy as np
import pandas as pd

from datetime import date
from folium.plugins import AntPath
from geopy.distance import geodesic
from collections import defaultdict
from geopy.geocoders import Nominatim
from folium.plugins import MarkerCluster
from spotipy.oauth2 import SpotifyOAuth
from geopy.distance import distance as geo_distance

# %% [markdown]
# ## Generate Candidate Locations

# %%
def generate_spiral_points_km(center_lat, center_lon, max_radius_km=300, num_points=500):
    points = []
    angle = 0
    scale_factor = max_radius_km / (math.sqrt(num_points))  # spread out nicely

    for i in range(num_points):
        radius_km = scale_factor * math.sqrt(i)
        angle += math.pi * (3 - math.sqrt(5))  # golden angle for uniform spacing

        # Convert polar to cartesian
        dx_km = radius_km * math.cos(angle)
        dy_km = radius_km * math.sin(angle)

        # Use geopy to get lat/lon offset from center
        destination = geo_distance(kilometers=math.hypot(dx_km, dy_km)).destination(
            (center_lat, center_lon), math.degrees(math.atan2(dy_km, dx_km))
        )

        points.append((destination.latitude, destination.longitude))

    return points

#  Generate the points from Bangalore
points = generate_spiral_points_km(origin_lat, origin_lon, max_radius_km, num_points)

# Preview first 5 points
print(f" Generated {len(points)} spiral points within {max_radius_km} km of Bangalore")
print("Sample points:")
for pt in points[:5]:
    print(f"   {pt}")
# Out:
#  Generated 1000 spiral points within 300 km of Bangalore
# Sample points:
#    (12.9716, 77.5946)
#    (12.979082403922487, 77.50749358973246)
#    (13.045368160343754, 77.69276315946094)
#    (12.825340436199092, 77.56823582066993)
#    (13.116290646662762, 77.5006840131555)

# %% [markdown]
# ## Get Weather Data

# %%
#  Initialize geocoder
geolocator = Nominatim(user_agent="weather_trip_planner")
geocode_cache = {}  #  cache for reverse geocoding

# %%
def get_weather(lat, lon, date="2024-05-24"):
    url = (
        "https://archive-api.open-meteo.com/v1/archive?"
        f"latitude={lat}&longitude={lon}"
        f"&start_date={date}&end_date={date}"
        "&daily=temperature_2m_max,temperature_2m_min,uv_index_max,weathercode,precipitation_sum,wind_speed_10m_max"
        "&timezone=Asia%2FKolkata"
    )

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        daily = data["daily"]
        return (
            daily["temperature_2m_max"][0],
            daily["temperature_2m_min"][0],
            daily["weathercode"][0],
            daily["precipitation_sum"][0],
            daily["wind_speed_10m_max"][0],
            daily["uv_index_max"][0]
        )

    except Exception as e:
        print(f"Error fetching weather for ({lat}, {lon}): {e}")
        return None, None, None, None, None, None

# %%
def reverse_geocode(lat, lon):
    key = (round(lat, 3), round(lon, 3))  #  avoid duplicates
    if key in geocode_cache:
        return geocode_cache[key]

    try:
        location = geolocator.reverse((lat, lon), exactly_one=True, language='en')
        name = location.address.split(",")[0] if location else "Unknown"
    except:
        name = "Unknown"

    geocode_cache[key] = name
    return name

# %%
weather_data = []

for idx, (lat, lon) in enumerate(points):
    max_temp, min_temp, weather_code, precipitation, wind_kmph, uv_index = get_weather(lat, lon)

    if max_temp is not None:
        location_name = reverse_geocode(lat, lon)

        weather_data.append({
            "Latitude": lat,
            "Longitude": lon,
            "Location": location_name,
            "Max Temp (°C)": max_temp,
            "Min Temp (°C)": min_temp,
            "Weather Code": weather_code,
            "Precipitation (mm)": precipitation,
            "Wind (km/h)": wind_kmph,
            "UV Index": uv_index
        })

        print(f" {idx+1}/{len(points)} fetched: {location_name} — {max_temp}°C, Wind: {wind_kmph} km/h, UV: {uv_index}")

    else:
        print(f" {idx+1}/{len(points)} skipped: failed to fetch weather")

    time.sleep(1)
# Out:
#  1/1000 fetched: St. Joseph's Indian High School — 29.8°C, Wind: 16.0 km/h, UV: None
#  2/1000 fetched: Srigandhakavalu — 30.2°C, Wind: 13.3 km/h, UV: None
#  3/1000 fetched: Maragondanahalli — 30.7°C, Wind: 16.3 km/h, UV: None
#  4/1000 fetched: Bilvaradhahalli — 30.0°C, Wind: 12.8 km/h, UV: None
#  5/1000 fetched: Kasaghattapura — 30.9°C, Wind: 16.1 km/h, UV: None
#  6/1000 fetched: Jantagondahalli — 30.8°C, Wind: 15.5 km/h, UV: None
#  7/1000 fetched: Koluru — 30.9°C, Wind: 12.7 km/h, UV: None
#  8/1000 fetched: Mutthugadhahalli — 31.1°C, Wind: 15.0 km/h, UV: None
#  9/1000 fetched: Doddahegade — 30.5°C, Wind: 15.8 km/h, UV: None
#  10/1000 fetched: Srinivasapura — 31.1°C, Wind: 17.9 km/h, UV: None
#  11/1000 fetched: Belamangala — 31.4°C, Wind: 16.3 km/h, UV: None
#  12/1000 fetched: Allalasandra — 31.1°C, Wind: 12.6 km/h, UV: None
#  13/1000 fetched: Chikka Tumakuru — 30.6°C, Wind: 18.3 km/h, UV: None
#  14/1000 fetched: Kalasthipuram — 31.8°C, Wind: 19.4 km/h, UV: None
#  15/1000 fetched: Polohalli — 30.4°C, Wind: 15.0 km/h, UV: None
#  16/1000 fetched: Timmappanahalli — 32.1°C, Wind: 18.4 km/h, UV: None
#  17/1000 fetched: Devarabetta — 30.4°C, Wind: 13.6 km/h, UV: None
#  18/1000 fetched: Doddabele — 30.6°C, Wind: 18.8 km/h, UV: None
#  19/1000 fetched: Nariganahalli — 31.7°C, Wind: 17.9 km/h, UV: None
#  20/1000 fetched: Vaderahalli — 30.9°C, Wind: 16.8 km/h, UV: None
#  21/1000 fetched: Chicckaballapur Road — 31.5°C, Wind: 16.1 km/h, UV: None
#  22/1000 fetched: Denkanikottai — 31.5°C, Wind: 20.7 km/h, UV: None
#  23/1000 fetched: Manniganahalli — 31.3°C, Wind: 16.4 km/h, UV: None
#  24/1000 fetched: Guttahalli — 32.1°C, Wind: 18.8 km/h, UV: None
#  25/1000 fetched: Thokkasandra — 31.6°C, Wind: 13.8 km/h, UV: None
#  26/1000 fetched: Narasapura — 31.0°C, Wind: 17.7 km/h, UV: None
#  27/1000 fetched: Shoolagiri — 32.3°C, Wind: 21.1 km/h, UV: None
#  28/1000 fetched: Akkuru — 30.5°C, Wind: 12.3 km/h, UV: None
#  29/1000 fetched: Kadagasenahalli — 33.8°C, Wind: 19.8 km/h, UV: None
#  30/1000 fetched: Denkanikottai — 30.6°C, Wind: 18.9 km/h, UV: None
#  31/1000 fetched: Kamalapura — 30.8°C, Wind: 15.2 km/h, UV: None
#  32/1000 fetched: Parshvaganahalli — 31.8°C, Wind: 18.4 km/h, UV: None
#  33/1000 fetched: Menasiganahalli — 30.5°C, Wind: 16.6 km/h, UV: None
#  34/1000 fetched: Chilenahalli — 32.3°C, Wind: 16.9 km/h, UV: None
#  35/1000 fetched: Shollagiri - Uddanapalli Road — 32.7°C, Wind: 20.2 km/h, UV: None
#  36/1000 fetched: Rajagere — 31.6°C, Wind: 17.2 km/h, UV: None
#  37/1000 fetched: Talagavara — 32.8°C, Wind: 16.9 km/h, UV: None
#  38/1000 fetched: Bijjahalli — 31.1°C, Wind: 12.8 km/h, UV: None
#  39/1000 fetched: S Gollahalli — 31.3°C, Wind: 20.0 km/h, UV: None
#  40/1000 fetched: ಹೊಸಹಳ್ಳಿ — 33.0°C, Wind: 19.6 km/h, UV: None
#  41/1000 fetched: Byadarahalli — 31.9°C, Wind: 16.5 km/h, UV: None
#  42/1000 fetched: Sulikunte — 32.7°C, Wind: 16.3 km/h, UV: None
#  43/1000 fetched: Denkanikottai — 32.2°C, Wind: 19.1 km/h, UV: None
#  44/1000 fetched: Dasarahalli — 31.8°C, Wind: 17.8 km/h, UV: None
#  45/1000 fetched: Vammasandra — 31.8°C, Wind: 19.8 km/h, UV: None
#  46/1000 fetched: Nagarasanakote — 31.0°C, Wind: 14.0 km/h, UV: None
#  47/1000 fetched: Machenahalli — 34.5°C, Wind: 20.2 km/h, UV: None
#  48/1000 fetched: Krishnagiri — 33.0°C, Wind: 19.7 km/h, UV: None
#  49/1000 fetched: Sonnanayakanahalli — 31.6°C, Wind: 22.7 km/h, UV: None
#  50/1000 fetched: Kundalagurki — 32.4°C, Wind: 17.1 km/h, UV: None
#  51/1000 fetched: Anchetty — 31.3°C, Wind: 13.7 km/h, UV: None
#  52/1000 fetched: Tumakuru — 31.8°C, Wind: 14.2 km/h, UV: None
#  53/1000 fetched: Kattihalli — 32.1°C, Wind: 17.8 km/h, UV: None
#  54/1000 fetched: Garakahalli — 31.3°C, Wind: 13.7 km/h, UV: None
#  55/1000 fetched: Venkatapura — 34.0°C, Wind: 16.6 km/h, UV: None
#  56/1000 fetched: Palakkodu — 32.5°C, Wind: 20.8 km/h, UV: None
#  57/1000 fetched: Gunnagere — 31.2°C, Wind: 12.4 km/h, UV: None
#  58/1000 fetched: Shettihalli — 32.2°C, Wind: 16.3 km/h, UV: None
#  59/1000 fetched: Shivanagaudanadoddi — 31.7°C, Wind: 9.6 km/h, UV: None
#  60/1000 fetched: SH160 — 32.7°C, Wind: 18.3 km/h, UV: None
#  61/1000 fetched: Mallappa Konda Temple Road — 30.5°C, Wind: 17.1 km/h, UV: None
#  62/1000 fetched: Haralahalli — 31.7°C, Wind: 12.2 km/h, UV: None
#  63/1000 fetched: Iragappanahalli — 33.3°C, Wind: 20.8 km/h, UV: None
#  64/1000 fetched: Anchetty — 30.4°C, Wind: 13.1 km/h, UV: None
#  65/1000 fetched: Hale Gubbi — 32.3°C, Wind: 11.9 km/h, UV: None
#  66/1000 fetched: Bengaluru Chennai Road — 32.5°C, Wind: 20.6 km/h, UV: None
#  67/1000 fetched: Ganalu — 31.6°C, Wind: 11.5 km/h, UV: None
#  68/1000 fetched: Gandhinagara — 35.2°C, Wind: 23.7 km/h, UV: None
#  69/1000 fetched: Krishnagiri — 33.8°C, Wind: 15.9 km/h, UV: None
#  70/1000 fetched: Kadashettihalli — 31.6°C, Wind: 17.1 km/h, UV: None
#  71/1000 fetched: Mugalamari — 32.5°C, Wind: 18.7 km/h, UV: None
#  72/1000 fetched: Anchetty — 30.3°C, Wind: 10.9 km/h, UV: None
#  73/1000 fetched: Rampura — 31.9°C, Wind: 16.5 km/h, UV: None
#  74/1000 fetched: Nilagirihalli — 32.2°C, Wind: 24.5 km/h, UV: None
#  75/1000 fetched: Kannali — 31.8°C, Wind: 12.9 km/h, UV: None
#  76/1000 fetched: Gudibanda - Hampasandra Road — 33.9°C, Wind: 19.1 km/h, UV: None
#  77/1000 fetched: Palakkodu — 32.5°C, Wind: 16.6 km/h, UV: None
#  78/1000 fetched: SH84 — 32.0°C, Wind: 11.5 km/h, UV: None
#  79/1000 fetched: Hosahalli — 31.8°C, Wind: 15.4 km/h, UV: None
#  80/1000 fetched: Ganigamangala — 31.7°C, Wind: 12.1 km/h, UV: None
#  81/1000 fetched: SH160 — 34.1°C, Wind: 18.2 km/h, UV: None
#  82/1000 fetched: Bargur — 33.6°C, Wind: 15.3 km/h, UV: None
#  83/1000 fetched: Naragalu — 32.1°C, Wind: 17.9 km/h, UV: None
#  84/1000 fetched: Gadigavarahalli — 34.0°C, Wind: 19.0 km/h, UV: None
#  85/1000 fetched: Billgundala — 32.9°C, Wind: 15.5 km/h, UV: None
#  86/1000 fetched: Satenahalli — 31.9°C, Wind: 15.8 km/h, UV: None
#  87/1000 fetched: Koravenuru — 32.0°C, Wind: 17.6 km/h, UV: None
#  88/1000 fetched: Marehalli — 31.4°C, Wind: 10.7 km/h, UV: None
#  89/1000 fetched: Cholasamudram — 35.5°C, Wind: 20.2 km/h, UV: None
#  90/1000 fetched: Krishnagiri — 32.6°C, Wind: 13.4 km/h, UV: None
#  91/1000 fetched: Byaladakere — 30.7°C, Wind: 14.5 km/h, UV: None
#  92/1000 fetched: Sonnepalli — 32.1°C, Wind: 13.0 km/h, UV: None
#  93/1000 fetched: Arabikere — 30.6°C, Wind: 17.1 km/h, UV: None
#  94/1000 fetched: Hanumanahalli — 33.2°C, Wind: 20.2 km/h, UV: None
#  95/1000 fetched: Giddeganipenta — 33.7°C, Wind: 20.8 km/h, UV: None
#  96/1000 fetched: Chikkatammanahalli — 31.6°C, Wind: 18.0 km/h, UV: None
#  97/1000 fetched: Kaganapalli — 34.1°C, Wind: 19.7 km/h, UV: None
#  98/1000 fetched: Pennagaram — 33.4°C, Wind: 14.0 km/h, UV: None
#  99/1000 fetched: Marashettihalli — 31.3°C, Wind: 14.3 km/h, UV: None
#  100/1000 fetched: Kallukere — 32.5°C, Wind: 18.0 km/h, UV: None
#  101/1000 fetched: Uganiya — 28.3°C, Wind: 17.1 km/h, UV: None
#  102/1000 fetched: Hosa Itakaloti — 35.0°C, Wind: 22.4 km/h, UV: None
#  103/1000 fetched: Bargur - Jagadevi Road — 33.5°C, Wind: 15.8 km/h, UV: None
#  104/1000 fetched: Kallukombari — 31.2°C, Wind: 20.0 km/h, UV: None
#  105/1000 fetched: Billandlahalli — 33.7°C, Wind: 15.6 km/h, UV: None
#  106/1000 fetched: Maruru — 32.4°C, Wind: 9.9 km/h, UV: None
#  107/1000 fetched: Shidlekona — 32.9°C, Wind: 14.2 km/h, UV: None
#  108/1000 fetched: Gummaraeddipalli Road — 32.4°C, Wind: 19.0 km/h, UV: None
#  109/1000 fetched: Kempegaudanakoppalu — 30.7°C, Wind: 15.8 km/h, UV: None
#  110/1000 fetched: Arumekalapalli — 35.3°C, Wind: 18.0 km/h, UV: None
#  111/1000 fetched: Karimangalam — 32.5°C, Wind: 16.8 km/h, UV: None
#  112/1000 fetched: NH150A — 31.1°C, Wind: 13.7 km/h, UV: None
#  113/1000 fetched: Kottayendulur — 32.9°C, Wind: 16.4 km/h, UV: None
#  114/1000 fetched: Ellemala — 30.3°C, Wind: 20.8 km/h, UV: None
#  115/1000 fetched: Hosahalli — 33.8°C, Wind: 19.6 km/h, UV: None
#  116/1000 fetched: Perumalappavuru — 33.5°C, Wind: 18.2 km/h, UV: None
#  117/1000 fetched: Bolenahalli — 31.0°C, Wind: 16.9 km/h, UV: None
#  118/1000 fetched: Dugginayakanapalli — 35.5°C, Wind: 16.7 km/h, UV: None
#  119/1000 fetched: Pennagaram — 30.6°C, Wind: 13.1 km/h, UV: None
#  120/1000 fetched: Muddanahalli — 31.4°C, Wind: 15.5 km/h, UV: None
#  121/1000 fetched: Mailapura — 32.5°C, Wind: 16.6 km/h, UV: None
#  122/1000 fetched: Talakadu — 30.9°C, Wind: 12.4 km/h, UV: None
#  123/1000 fetched: Yerragunta — 35.8°C, Wind: 15.8 km/h, UV: None
#  124/1000 fetched: Pochampalli — 33.0°C, Wind: 17.1 km/h, UV: None
#  125/1000 fetched: Mallenahalli — 30.6°C, Wind: 16.1 km/h, UV: None
#  126/1000 fetched: MDR — 32.5°C, Wind: 16.2 km/h, UV: None
#  127/1000 fetched: Tokere — 27.1°C, Wind: 9.3 km/h, UV: None
#  128/1000 fetched: Doddanahali — 33.5°C, Wind: 17.6 km/h, UV: None
#  129/1000 fetched: Peddur — 32.9°C, Wind: 22.2 km/h, UV: None
#  130/1000 fetched: Mundugadore — 31.0°C, Wind: 16.8 km/h, UV: None
#  131/1000 fetched: Pesalaparti — 35.9°C, Wind: 18.6 km/h, UV: None
#  132/1000 fetched: Dharmapuri — 31.8°C, Wind: 17.1 km/h, UV: None
#  133/1000 fetched: Guladahalli — 30.8°C, Wind: 13.6 km/h, UV: None
#  134/1000 fetched: Santamambadi — 33.6°C, Wind: 16.6 km/h, UV: None
#  135/1000 fetched: Hanur taluk — 28.5°C, Wind: 20.1 km/h, UV: None
#  136/1000 fetched: NH544E — 34.7°C, Wind: 20.5 km/h, UV: None
#  137/1000 fetched: Tirupathur — 33.8°C, Wind: 13.6 km/h, UV: None
#  138/1000 fetched: Koravanagundi — 29.9°C, Wind: 17.0 km/h, UV: None
#  139/1000 fetched: Komatampalle — 36.6°C, Wind: 12.8 km/h, UV: None
#  140/1000 fetched: Pennagaram — 33.1°C, Wind: 6.6 km/h, UV: None
#  141/1000 fetched: Salapura — 32.1°C, Wind: 16.8 km/h, UV: None
#  142/1000 fetched: Pathapeta — 33.7°C, Wind: 21.7 km/h, UV: None
#  143/1000 fetched: Kiragasuru — 30.8°C, Wind: 16.9 km/h, UV: None
#  144/1000 fetched: Nottupalli — 35.9°C, Wind: 19.6 km/h, UV: None
#  145/1000 fetched: Karimangalam — 32.9°C, Wind: 19.7 km/h, UV: None
#  146/1000 fetched: Kabballi — 29.7°C, Wind: 14.1 km/h, UV: None
#  147/1000 fetched: Bodagampalle — 33.6°C, Wind: 14.0 km/h, UV: None
#  148/1000 fetched: Hanur taluk — 30.9°C, Wind: 13.8 km/h, UV: None
#  149/1000 fetched: MDR — 34.1°C, Wind: 20.0 km/h, UV: None
#  150/1000 fetched: Vaniyambadi — 35.2°C, Wind: 11.4 km/h, UV: None
#  151/1000 fetched: Deshavalli — 30.9°C, Wind: 16.3 km/h, UV: None
#  152/1000 fetched: ಬೋವಿಪಲ್ಲಿ — 36.1°C, Wind: 18.4 km/h, UV: None
#  153/1000 fetched: Nallampalli — 30.3°C, Wind: 15.3 km/h, UV: None
#  154/1000 fetched: Chikkenahalli — 31.2°C, Wind: 18.4 km/h, UV: None
#  155/1000 fetched: Polepalle — 33.5°C, Wind: 19.5 km/h, UV: None
#  156/1000 fetched: Old NH948 — 29.2°C, Wind: 15.1 km/h, UV: None
#  157/1000 fetched: Venkatapura — 36.1°C, Wind: 19.1 km/h, UV: None
#  158/1000 fetched: Pochampalli — 33.5°C, Wind: 16.4 km/h, UV: None
#  159/1000 fetched: Madihalli — 29.8°C, Wind: 13.7 km/h, UV: None
#  160/1000 fetched: Gollavandlapalle — 36.9°C, Wind: 20.1 km/h, UV: None
#  161/1000 fetched: Anthiyur — 32.7°C, Wind: 11.1 km/h, UV: None
#  162/1000 fetched: Sorekunte — 33.3°C, Wind: 21.4 km/h, UV: None
#  163/1000 fetched: Gudiyatham — 35.9°C, Wind: 19.1 km/h, UV: None
#  164/1000 fetched: Chikkahalli — 30.6°C, Wind: 15.7 km/h, UV: None
#  165/1000 fetched: MDR — 35.7°C, Wind: 20.5 km/h, UV: None
#  166/1000 fetched: Dharmapuri — 28.1°C, Wind: 15.9 km/h, UV: None
#  167/1000 fetched: Tiptur - Chennarayapatna Road — 30.3°C, Wind: 13.7 km/h, UV: None
#  168/1000 fetched: MDR — 33.6°C, Wind: 19.9 km/h, UV: None
#  169/1000 fetched: Andipalya — 27.8°C, Wind: 9.4 km/h, UV: None
#  170/1000 fetched: Singapalli — 34.0°C, Wind: 20.0 km/h, UV: None
#  171/1000 fetched: Bothanur — 33.7°C, Wind: 15.2 km/h, UV: None
#  172/1000 fetched: Kamanahalli — 30.5°C, Wind: 16.6 km/h, UV: None
#  173/1000 fetched: Nallacheruvu — 36.6°C, Wind: 14.4 km/h, UV: None
#  174/1000 fetched: Raman Nagar — 31.2°C, Wind: 14.0 km/h, UV: None
#  175/1000 fetched: Boranakanive — 32.7°C, Wind: 18.6 km/h, UV: None
#  176/1000 fetched: MDR — 34.6°C, Wind: 22.9 km/h, UV: None
#  177/1000 fetched: Karya — 29.3°C, Wind: 16.0 km/h, UV: None
#  178/1000 fetched: Kogira — 36.1°C, Wind: 26.3 km/h, UV: None
#  179/1000 fetched: Doddampatti — 33.5°C, Wind: 18.1 km/h, UV: None
#  180/1000 fetched: Chaudenahalli — 29.9°C, Wind: 12.3 km/h, UV: None
#  181/1000 fetched: Jallavandlapalle — 35.9°C, Wind: 17.7 km/h, UV: None
#  182/1000 fetched: Anthiyur — 30.9°C, Wind: 13.2 km/h, UV: None
#  183/1000 fetched: Gundappa Chikkenahalli — 34.0°C, Wind: 21.8 km/h, UV: None
#  184/1000 fetched: Kavanūrthattu — 34.8°C, Wind: 16.0 km/h, UV: None
#  185/1000 fetched: Krishnaraja Sagara Road — 30.0°C, Wind: 18.5 km/h, UV: None
#  186/1000 fetched: Nayanikota — 36.0°C, Wind: 16.8 km/h, UV: None
#  187/1000 fetched: Bommiampatty — 30.5°C, Wind: 17.2 km/h, UV: None
#  188/1000 fetched: Tiptur to Huliyar road — 31.7°C, Wind: 17.1 km/h, UV: None
#  189/1000 fetched: Chinna Ketanpalle — 33.1°C, Wind: 17.2 km/h, UV: None
#  190/1000 fetched: Hondarabalu — 28.4°C, Wind: 10.7 km/h, UV: None
#  191/1000 fetched: Bommatanahalli — 35.8°C, Wind: 25.9 km/h, UV: None
#  192/1000 fetched: Tirupathur — 33.3°C, Wind: 13.4 km/h, UV: None
#  193/1000 fetched: Kalenahalli — 29.8°C, Wind: 12.7 km/h, UV: None
#  194/1000 fetched: Chevutivaripalle — 37.8°C, Wind: 17.1 km/h, UV: None
#  195/1000 fetched: Mettuthanapatti — 31.4°C, Wind: 11.7 km/h, UV: None
#  196/1000 fetched: Mavinamadu — 32.9°C, Wind: 18.9 km/h, UV: None
#  197/1000 fetched: Gudiyatham — 36.4°C, Wind: 18.9 km/h, UV: None
#  198/1000 fetched: Toremavu — 30.2°C, Wind: 14.5 km/h, UV: None
#  199/1000 fetched: Munimadugu — 37.4°C, Wind: 22.3 km/h, UV: None
#  200/1000 fetched: Pappireddipatti — 31.6°C, Wind: 19.7 km/h, UV: None
#  201/1000 fetched: Chindenahally — 30.5°C, Wind: 13.1 km/h, UV: None
#  202/1000 fetched: Vayalpadu — 36.0°C, Wind: 19.9 km/h, UV: None
#  203/1000 fetched: Thalavadi — 30.1°C, Wind: 14.2 km/h, UV: None
#  204/1000 fetched: Kenkere — 34.9°C, Wind: 17.6 km/h, UV: None
#  205/1000 fetched: Pūngulam — 33.2°C, Wind: 12.1 km/h, UV: None
#  206/1000 fetched: Kallahalli — 29.7°C, Wind: 17.7 km/h, UV: None
#  207/1000 fetched: Bathalapalle — 36.5°C, Wind: 13.8 km/h, UV: None
#  208/1000 fetched: Muradan colony — 30.4°C, Wind: 12.6 km/h, UV: None
#  209/1000 fetched: NH69 — 31.9°C, Wind: 15.6 km/h, UV: None
#  210/1000 fetched: Devalampeta — 35.3°C, Wind: 18.8 km/h, UV: None
#  211/1000 fetched: Bedarapura — 28.4°C, Wind: 13.7 km/h, UV: None
#  212/1000 fetched: Kyataganacherlu — 35.9°C, Wind: 20.8 km/h, UV: None
#  213/1000 fetched: Nadupatti — 34.2°C, Wind: 16.7 km/h, UV: None
#  214/1000 fetched: Nadanahalli — 29.8°C, Wind: 14.3 km/h, UV: None
#  215/1000 fetched: Bathinigaripalle — 36.9°C, Wind: 21.4 km/h, UV: None
#  216/1000 fetched: Chellampalayam - Burgur - Kollegal Road — 31.2°C, Wind: 10.0 km/h, UV: None
#  217/1000 fetched: Dandikere — 34.1°C, Wind: 18.1 km/h, UV: None
#  218/1000 fetched: Pūduvenkatappankottayi — 35.8°C, Wind: 15.8 km/h, UV: None
#  219/1000 fetched: Dhanagalli — 29.0°C, Wind: 13.4 km/h, UV: None
#  220/1000 fetched: Bukkapatnam — 35.6°C, Wind: 16.4 km/h, UV: None
#  221/1000 fetched: Yercaud — 26.1°C, Wind: 10.8 km/h, UV: None
#  222/1000 fetched: Dasihalli — 30.7°C, Wind: 13.8 km/h, UV: None
#  223/1000 fetched: Kottapalle — 34.7°C, Wind: 17.9 km/h, UV: None
#  224/1000 fetched: Punajanuru — 26.1°C, Wind: 14.0 km/h, UV: None
#  225/1000 fetched: Bellibatlu — 34.2°C, Wind: 19.0 km/h, UV: None
#  226/1000 fetched: Kuppanattam — 34.4°C, Wind: 10.5 km/h, UV: None
#  227/1000 fetched: NH373 — 29.4°C, Wind: 15.5 km/h, UV: None
#  228/1000 fetched: Pedakantivaripalli — 37.2°C, Wind: 20.5 km/h, UV: None
#  229/1000 fetched: Chittoor - Pakkanadu - Jalagandapuram Road — 30.4°C, Wind: 13.2 km/h, UV: None
#  230/1000 fetched: Arashinagundi — 31.6°C, Wind: 15.6 km/h, UV: None
#  231/1000 fetched: Diguvakantalacheruvu — 35.6°C, Wind: 19.9 km/h, UV: None
#  232/1000 fetched: Baguru — 28.5°C, Wind: 16.6 km/h, UV: None
#  233/1000 fetched: Chinnapeta — 37.6°C, Wind: 20.8 km/h, UV: None
#  234/1000 fetched: Kelapaarai — 33.5°C, Wind: 9.8 km/h, UV: None
#  235/1000 fetched: Valagerehalli — 29.7°C, Wind: 11.6 km/h, UV: None
#  236/1000 fetched: Nagarajapuram — 36.1°C, Wind: 14.0 km/h, UV: None
#  237/1000 fetched: Sathyamangalam — 29.5°C, Wind: 10.8 km/h, UV: None
#  238/1000 fetched: Kanajanahalli — 35.3°C, Wind: 19.7 km/h, UV: None
#  239/1000 fetched: Pudupattu — 32.7°C, Wind: 13.7 km/h, UV: None
#  240/1000 fetched: NH275 — 29.4°C, Wind: 13.4 km/h, UV: None
#  241/1000 fetched: Erravankapalle — 37.6°C, Wind: 16.0 km/h, UV: None
#  242/1000 fetched: Karuppur - Vellapatty - Thathiyangarpatty Road — 29.9°C, Wind: 12.6 km/h, UV: None
#  243/1000 fetched: Donanakatte — 31.7°C, Wind: 16.3 km/h, UV: None
#  244/1000 fetched: Muchhukalva — 32.4°C, Wind: 16.8 km/h, UV: None
#  245/1000 fetched: Bisalavadi — 26.2°C, Wind: 13.4 km/h, UV: None
#  246/1000 fetched: Bettadakelaginahalli — 34.8°C, Wind: 23.8 km/h, UV: None
#  247/1000 fetched: Chengam — 35.4°C, Wind: 19.3 km/h, UV: None
#  248/1000 fetched: Holenarasipura — 29.0°C, Wind: 12.2 km/h, UV: None
#  249/1000 fetched: Donamareddigaripalle — 37.6°C, Wind: 19.0 km/h, UV: None
#  250/1000 fetched: Guruvareddiyur — 30.6°C, Wind: 11.0 km/h, UV: None
#  251/1000 fetched: Hiriyur — 33.5°C, Wind: 18.2 km/h, UV: None
#  252/1000 fetched: Kalanipākkam — 37.6°C, Wind: 17.3 km/h, UV: None
#  253/1000 fetched: Hullahalli — 28.8°C, Wind: 13.4 km/h, UV: None
#  254/1000 fetched: Kaniyampalli — 37.8°C, Wind: 16.7 km/h, UV: None
#  255/1000 fetched: Vazhapadi — 30.1°C, Wind: 8.3 km/h, UV: None
#  256/1000 fetched: SH102 — 31.3°C, Wind: 13.2 km/h, UV: None
#  257/1000 fetched: Kalakada - Kalikiri - Somala Road — 35.5°C, Wind: 19.6 km/h, UV: None
#  258/1000 fetched: Thalavadi — 24.4°C, Wind: 14.0 km/h, UV: None
#  259/1000 fetched: Shiddeshvaranadurga — 35.3°C, Wind: 18.3 km/h, UV: None
#  260/1000 fetched: Kalasapakkam — 33.2°C, Wind: 10.8 km/h, UV: None
#  261/1000 fetched: Dodda Koppalu — 29.0°C, Wind: 18.8 km/h, UV: None
#  262/1000 fetched: Eguva Nangivandlapalli — 37.4°C, Wind: 18.3 km/h, UV: None
#  263/1000 fetched: M K Rd — 30.5°C, Wind: 15.8 km/h, UV: None
#  264/1000 fetched: Malappanahalli — 32.3°C, Wind: 15.7 km/h, UV: None
#  265/1000 fetched: MDR — 37.2°C, Wind: 10.1 km/h, UV: None
#  266/1000 fetched: Kilagere — 27.3°C, Wind: 14.7 km/h, UV: None
#  267/1000 fetched: Gangampalli — 37.1°C, Wind: 23.4 km/h, UV: None
#  268/1000 fetched: Kottappatti — 34.9°C, Wind: 14.2 km/h, UV: None
#  269/1000 fetched: Chikka Aladahalli — 29.3°C, Wind: 10.8 km/h, UV: None
#  270/1000 fetched: Nandigadda — 37.9°C, Wind: 17.1 km/h, UV: None
#  271/1000 fetched: Anthiyur — 29.9°C, Wind: 9.1 km/h, UV: None
#  272/1000 fetched: Hemadala — 34.3°C, Wind: 18.1 km/h, UV: None
#  273/1000 fetched: Nekkini — 34.0°C, Wind: 14.4 km/h, UV: None
#  274/1000 fetched: Kendagannapura — 29.0°C, Wind: 11.6 km/h, UV: None
#  275/1000 fetched: Guddampalli Thanda — 38.5°C, Wind: 18.5 km/h, UV: None
#  276/1000 fetched: Pallathur — 29.3°C, Wind: 9.7 km/h, UV: None
#  277/1000 fetched: Hosahalli — 31.3°C, Wind: 15.7 km/h, UV: None
#  278/1000 fetched: Pachcharlamakulapalle — 35.3°C, Wind: 14.2 km/h, UV: None
#  279/1000 fetched: Thalavadi — 25.4°C, Wind: 12.6 km/h, UV: None
#  280/1000 fetched: Obaganapalli - Jalodu Road — 35.6°C, Wind: 23.8 km/h, UV: None
#  281/1000 fetched: Thandrampet - Kottakulam Road — 35.1°C, Wind: 20.9 km/h, UV: None
#  282/1000 fetched: Guragundi — 28.3°C, Wind: 14.0 km/h, UV: None
#  283/1000 fetched: Kallurupalle — 39.1°C, Wind: 16.1 km/h, UV: None
#  284/1000 fetched: Sankari — 29.9°C, Wind: 12.8 km/h, UV: None
#  285/1000 fetched: Timmanahalli — 32.2°C, Wind: 16.8 km/h, UV: None
#  286/1000 fetched: Chittapara — 37.2°C, Wind: 19.1 km/h, UV: None
#  287/1000 fetched: Devarayashettipura — 27.4°C, Wind: 12.6 km/h, UV: None
#  288/1000 fetched: Munchurami — 37.9°C, Wind: 19.6 km/h, UV: None
#  289/1000 fetched: Pappireddipatti — 30.4°C, Wind: 8.7 km/h, UV: None
#  290/1000 fetched: Yalagunda — 29.7°C, Wind: 12.5 km/h, UV: None
#  291/1000 fetched: Nilappagaripalle — 36.7°C, Wind: 21.2 km/h, UV: None
#  292/1000 fetched: Chinna Swamy engineer farm — 30.8°C, Wind: 9.2 km/h, UV: None
#  293/1000 fetched: Vishvanathapura — 35.4°C, Wind: 18.8 km/h, UV: None
#  294/1000 fetched: Kalasapakkam — 35.6°C, Wind: 12.0 km/h, UV: None
#  295/1000 fetched: Kottegala — 28.2°C, Wind: 11.9 km/h, UV: None
#  296/1000 fetched: Vepalapalli — 36.7°C, Wind: 16.6 km/h, UV: None
#  297/1000 fetched: Salem South — 30.6°C, Wind: 12.6 km/h, UV: None
#  298/1000 fetched: Vakkalagere — 32.6°C, Wind: 17.6 km/h, UV: None
#  299/1000 fetched: Ramāpuram — 36.9°C, Wind: 12.6 km/h, UV: None
#  300/1000 fetched: Daribeguru — 26.1°C, Wind: 12.4 km/h, UV: None
#  301/1000 fetched: Kanaganapalle — 36.5°C, Wind: 25.5 km/h, UV: None
#  302/1000 fetched: Thandrampet — 33.9°C, Wind: 16.6 km/h, UV: None
#  303/1000 fetched: Uduvare — 29.1°C, Wind: 12.7 km/h, UV: None
#  304/1000 fetched: Erradaddipalli — 38.1°C, Wind: 16.1 km/h, UV: None
#  305/1000 fetched: Bhavani — 31.1°C, Wind: 11.8 km/h, UV: None
#  306/1000 fetched: Thadapina Chinnammahalli — 33.3°C, Wind: 19.3 km/h, UV: None
#  307/1000 fetched: Adukkamparai — 37.7°C, Wind: 14.3 km/h, UV: None
#  308/1000 fetched: Devalapura — 28.0°C, Wind: 9.8 km/h, UV: None
#  309/1000 fetched: MDR — 38.5°C, Wind: 18.4 km/h, UV: None
#  310/1000 fetched: Belur — 31.3°C, Wind: 12.8 km/h, UV: None
#  311/1000 fetched: NH73 — 31.7°C, Wind: 12.2 km/h, UV: None
#  312/1000 fetched: MDR — 36.1°C, Wind: 20.0 km/h, UV: None
#  313/1000 fetched: Thalavadi — 29.4°C, Wind: 13.2 km/h, UV: None
#  314/1000 fetched: Makadiki Tanda — 35.5°C, Wind: 18.4 km/h, UV: None
#  315/1000 fetched: Tiruvannamalai - Kanji Road — 35.0°C, Wind: 15.8 km/h, UV: None
#  316/1000 fetched: ಸುರಗಹಳ್ಳಿ — 28.0°C, Wind: 18.6 km/h, UV: None
#  317/1000 fetched: Giddankipalli — 38.1°C, Wind: 17.3 km/h, UV: None
#  318/1000 fetched: Sankari — 29.9°C, Wind: 12.5 km/h, UV: None
#  319/1000 fetched: Honnenahalli — 32.4°C, Wind: 17.1 km/h, UV: None
#  320/1000 fetched: MDR — 37.8°C, Wind: 9.7 km/h, UV: None
#  321/1000 fetched: Bhimanabidu — 25.7°C, Wind: 12.0 km/h, UV: None
#  322/1000 fetched: Palacherla — 37.4°C, Wind: 24.6 km/h, UV: None
#  323/1000 fetched: Sankarapuram — 31.9°C, Wind: 12.6 km/h, UV: None
#  324/1000 fetched: Madvapura — 28.6°C, Wind: 13.5 km/h, UV: None
#  325/1000 fetched: MDR — 37.9°C, Wind: 13.3 km/h, UV: None
#  326/1000 fetched: Gobichettipalayam — 30.1°C, Wind: 13.0 km/h, UV: None
#  327/1000 fetched: Gopanahalli — 34.4°C, Wind: 23.2 km/h, UV: None
#  328/1000 fetched: Chinnapushpagiri — 34.7°C, Wind: 11.4 km/h, UV: None
#  329/1000 fetched: Nalluru Pala — 27.8°C, Wind: 11.3 km/h, UV: None
#  330/1000 fetched: MDR — 39.0°C, Wind: 19.3 km/h, UV: None
#  331/1000 fetched: Salem — 29.8°C, Wind: 14.2 km/h, UV: None
#  332/1000 fetched: Chikkanayakanahalli — 31.9°C, Wind: 17.8 km/h, UV: None
#  333/1000 fetched: Madigapalle — 36.0°C, Wind: 24.3 km/h, UV: None
#  334/1000 fetched: Thalavadi — 29.8°C, Wind: 9.7 km/h, UV: None
#  335/1000 fetched: Duradakunta — 37.0°C, Wind: 24.7 km/h, UV: None
#  336/1000 fetched: Thandrampet — 35.2°C, Wind: 21.7 km/h, UV: None
#  337/1000 fetched: Arakalagudu taluk — 28.2°C, Wind: 14.2 km/h, UV: None
#  338/1000 fetched: Kuruvandlapalle — 38.7°C, Wind: 12.5 km/h, UV: None
#  339/1000 fetched: Vaikkalmedu — 30.9°C, Wind: 9.7 km/h, UV: None
#  340/1000 fetched: Upparigenahalli — 31.5°C, Wind: 18.9 km/h, UV: None
#  341/1000 fetched: Katpadi — 38.3°C, Wind: 16.3 km/h, UV: None
#  342/1000 fetched: Kandalike — 27.0°C, Wind: 11.9 km/h, UV: None
#  343/1000 fetched: Lingareddipalle — 38.4°C, Wind: 18.4 km/h, UV: None
#  344/1000 fetched: Ramamoorthy Nagar — 28.9°C, Wind: 13.0 km/h, UV: None
#  345/1000 fetched: Mayagondanahalli Gadi — 30.5°C, Wind: 12.3 km/h, UV: None
#  346/1000 fetched: Balijapalle — 37.4°C, Wind: 17.1 km/h, UV: None
#  347/1000 fetched: Crusher Rd — 30.1°C, Wind: 9.2 km/h, UV: None
#  348/1000 fetched: Nagagondanahalli — 36.2°C, Wind: 19.2 km/h, UV: None
#  349/1000 fetched: Tiruvannamalai — 35.7°C, Wind: 16.0 km/h, UV: None
#  350/1000 fetched: Hemmige — 27.6°C, Wind: 10.9 km/h, UV: None
#  351/1000 fetched: Chintalajutur — 39.9°C, Wind: 16.3 km/h, UV: None
#  352/1000 fetched: Morangam — 30.8°C, Wind: 11.5 km/h, UV: None
#  353/1000 fetched: Sanihalli — 32.4°C, Wind: 17.7 km/h, UV: None
#  354/1000 fetched: MDR — 37.0°C, Wind: 9.7 km/h, UV: None
#  355/1000 fetched: Bandipura — 24.9°C, Wind: 11.1 km/h, UV: None
#  356/1000 fetched: Goridindla — 37.4°C, Wind: 33.5 km/h, UV: None
#  357/1000 fetched: Sankarapuram — 31.0°C, Wind: 12.6 km/h, UV: None
#  358/1000 fetched: Singodanahalli — 29.0°C, Wind: 17.4 km/h, UV: None
#  359/1000 fetched: Malapalle — 39.8°C, Wind: 21.5 km/h, UV: None
#  360/1000 fetched: Perundurai — 30.8°C, Wind: 14.4 km/h, UV: None
#  361/1000 fetched: Ennegere — 33.2°C, Wind: 20.9 km/h, UV: None
#  362/1000 fetched: Chekkalianūr — 36.9°C, Wind: 15.3 km/h, UV: None
#  363/1000 fetched: Hirehalli B — 27.4°C, Wind: 9.9 km/h, UV: None
#  364/1000 fetched: Parnapalle — 39.5°C, Wind: 19.7 km/h, UV: None
#  365/1000 fetched: Nagapatnam — 30.7°C, Wind: 16.8 km/h, UV: None
#  366/1000 fetched: Panchehosalli — 31.8°C, Wind: 14.8 km/h, UV: None
#  367/1000 fetched: Bandaruvdlapalle — 36.0°C, Wind: 17.0 km/h, UV: None
#  368/1000 fetched: Kadasholai — 22.2°C, Wind: 9.6 km/h, UV: None
#  369/1000 fetched: Sugepalli — 36.7°C, Wind: 20.9 km/h, UV: None
#  370/1000 fetched: Tiruvannamalai — 35.0°C, Wind: 21.3 km/h, UV: None
#  371/1000 fetched: Jagenalli — 28.4°C, Wind: 9.8 km/h, UV: None
#  372/1000 fetched: Pichikuntlavandlapalli — 37.9°C, Wind: 14.1 km/h, UV: None
#  373/1000 fetched: Andipalayam — 29.3°C, Wind: 11.0 km/h, UV: None
#  374/1000 fetched: Gulihatti — 31.3°C, Wind: 19.2 km/h, UV: None
#  375/1000 fetched: Keeraisathu Road — 38.3°C, Wind: 11.1 km/h, UV: None
#  376/1000 fetched: Gundlupet taluk — 26.6°C, Wind: 9.6 km/h, UV: None
#  377/1000 fetched: Ram Nagar — 38.1°C, Wind: 21.0 km/h, UV: None
#  378/1000 fetched: Sankarapuram — 29.0°C, Wind: 13.0 km/h, UV: None
#  379/1000 fetched: Beluru taluk — 28.9°C, Wind: 15.0 km/h, UV: None
#  380/1000 fetched: Chandrajupalle — 39.0°C, Wind: 16.4 km/h, UV: None
#  381/1000 fetched: Avanashi — 29.8°C, Wind: 14.3 km/h, UV: None
#  382/1000 fetched: Devarahalli — 34.5°C, Wind: 24.7 km/h, UV: None
#  383/1000 fetched: Chetpet — 36.7°C, Wind: 15.5 km/h, UV: None
#  384/1000 fetched: Ponnampete taluk — 27.6°C, Wind: 12.3 km/h, UV: None
#  385/1000 fetched: Pulivendula-Tadipatri Road — 39.9°C, Wind: 16.3 km/h, UV: None
#  386/1000 fetched: Palaniappanur — 30.6°C, Wind: 11.4 km/h, UV: None
#  387/1000 fetched: Giriyapura — 31.1°C, Wind: 20.0 km/h, UV: None
#  388/1000 fetched: Pathagunta — 36.6°C, Wind: 20.4 km/h, UV: None
#  389/1000 fetched: Benthatty — 24.7°C, Wind: 7.9 km/h, UV: None
#  390/1000 fetched: Sibhavi — 38.0°C, Wind: 28.2 km/h, UV: None
#  391/1000 fetched: Sankarapuram — 34.1°C, Wind: 12.8 km/h, UV: None
#  392/1000 fetched: Kujageri — 27.5°C, Wind: 16.6 km/h, UV: None
#  393/1000 fetched: Neelakantharaopeta — 38.2°C, Wind: 14.7 km/h, UV: None
#  394/1000 fetched: Pungampadi — 30.0°C, Wind: 14.9 km/h, UV: None
#  395/1000 fetched: Devarahatti — 31.2°C, Wind: 22.3 km/h, UV: None
#  396/1000 fetched: Arcot — 37.4°C, Wind: 14.0 km/h, UV: None
#  397/1000 fetched: Jakkahalli — 27.2°C, Wind: 9.1 km/h, UV: None
#  398/1000 fetched: Jangamreddipalle — 38.9°C, Wind: 18.7 km/h, UV: None
#  399/1000 fetched: Nainar Palayam — 31.3°C, Wind: 15.3 km/h, UV: None
#  400/1000 fetched: Sadarahalli — 31.0°C, Wind: 10.0 km/h, UV: None
#  401/1000 fetched: Sarangutapalle — 36.7°C, Wind: 17.9 km/h, UV: None
#  402/1000 fetched: Irumborai — 29.1°C, Wind: 8.0 km/h, UV: None
#  403/1000 fetched: Polepalli — 36.3°C, Wind: 18.6 km/h, UV: None
#  404/1000 fetched: Kilpennathur — 35.7°C, Wind: 19.0 km/h, UV: None
#  405/1000 fetched: Sera Je — 26.9°C, Wind: 16.3 km/h, UV: None
#  406/1000 fetched: MDR — 40.4°C, Wind: 20.5 km/h, UV: None
#  407/1000 fetched: Ayyakattupalayam — 29.4°C, Wind: 10.5 km/h, UV: None
#  408/1000 fetched: Gangasamudra — 31.6°C, Wind: 17.4 km/h, UV: None
#  409/1000 fetched: Kappakandriga — 38.5°C, Wind: 11.4 km/h, UV: None
#  410/1000 fetched: Gudalur — 24.4°C, Wind: 9.8 km/h, UV: None
#  411/1000 fetched: Talupuru — 37.8°C, Wind: 29.2 km/h, UV: None
#  412/1000 fetched: Vadakkamandal — 33.6°C, Wind: 12.4 km/h, UV: None
#  413/1000 fetched: Masuvalli — 29.0°C, Wind: 13.4 km/h, UV: None
#  414/1000 fetched: Mallappandyudigaripalle — 38.5°C, Wind: 18.3 km/h, UV: None
#  415/1000 fetched: Uthukuli — 29.7°C, Wind: 16.9 km/h, UV: None
#  416/1000 fetched: Bommakkanahalli — 33.6°C, Wind: 22.3 km/h, UV: None
#  417/1000 fetched: Cheyyar — 37.4°C, Wind: 15.7 km/h, UV: None
#  418/1000 fetched: Ponnampete taluk — 26.7°C, Wind: 12.2 km/h, UV: None
#  419/1000 fetched: Krishnapuram — 39.8°C, Wind: 17.7 km/h, UV: None
#  420/1000 fetched: Pudu Palapatty — 29.4°C, Wind: 10.5 km/h, UV: None
#  421/1000 fetched: Biruru — 29.9°C, Wind: 18.2 km/h, UV: None
#  422/1000 fetched: Pullaiahgaripalle Hw — 38.6°C, Wind: 8.8 km/h, UV: None
#  423/1000 fetched: Coonoor - Kattabettu Road — 18.6°C, Wind: 12.8 km/h, UV: None
#  424/1000 fetched: Brahmananpalli — 37.1°C, Wind: 20.2 km/h, UV: None
#  425/1000 fetched: Cuddalore - Chittoor Road — 34.7°C, Wind: 14.5 km/h, UV: None
#  426/1000 fetched: Alekatte — 25.4°C, Wind: 11.2 km/h, UV: None
#  427/1000 fetched: Pendlimarri — 39.3°C, Wind: 17.4 km/h, UV: None
#  428/1000 fetched: Modakkurichi — 29.9°C, Wind: 9.7 km/h, UV: None
#  429/1000 fetched: Hanumakatte — 31.4°C, Wind: 22.2 km/h, UV: None
#  430/1000 fetched: Wallajah — 38.8°C, Wind: 12.3 km/h, UV: None
#  431/1000 fetched: Sulthanbathery — 25.9°C, Wind: 7.4 km/h, UV: None
#  432/1000 fetched: NH544D;NH544F — 38.9°C, Wind: 18.2 km/h, UV: None
#  433/1000 fetched: Bharathiyar Educational Institure — 33.0°C, Wind: 20.0 km/h, UV: None
#  434/1000 fetched: Hadihalli — 28.3°C, Wind: 16.0 km/h, UV: None
#  435/1000 fetched: Pullampeta — 36.5°C, Wind: 13.0 km/h, UV: None
#  436/1000 fetched: Avanashi — 29.6°C, Wind: 13.5 km/h, UV: None
#  437/1000 fetched: Hirehalli — 35.1°C, Wind: 25.7 km/h, UV: None
#  438/1000 fetched: Melmalaiyanur — 36.4°C, Wind: 17.1 km/h, UV: None
#  439/1000 fetched: SH89 — 26.6°C, Wind: 13.5 km/h, UV: None
#  440/1000 fetched: Jammalamadugu - Kadiri Road — 39.2°C, Wind: 14.4 km/h, UV: None
#  441/1000 fetched: Komaragoundanur — 30.1°C, Wind: 10.6 km/h, UV: None
#  442/1000 fetched: Shivani — 30.7°C, Wind: 16.9 km/h, UV: None
#  443/1000 fetched: Cheruvumundarakandriga — 38.4°C, Wind: 11.9 km/h, UV: None
#  444/1000 fetched: Pykara — 17.7°C, Wind: 9.4 km/h, UV: None
#  445/1000 fetched: Jayapuram — 37.8°C, Wind: 29.2 km/h, UV: None
#  446/1000 fetched: Sankarapuram — 33.8°C, Wind: 14.3 km/h, UV: None
#  447/1000 fetched: Nudarahalli — 26.6°C, Wind: 15.5 km/h, UV: None
#  448/1000 fetched: Veeraballe — 35.8°C, Wind: 15.5 km/h, UV: None
#  449/1000 fetched: Perundurai — 28.8°C, Wind: 16.3 km/h, UV: None
#  450/1000 fetched: Rayanahalli — 32.6°C, Wind: 23.3 km/h, UV: None
#  451/1000 fetched: Parikalapattu — 38.1°C, Wind: 15.5 km/h, UV: None
#  452/1000 fetched: Bavali — 26.3°C, Wind: 7.3 km/h, UV: None
#  453/1000 fetched: Narayanareddipalle — 39.4°C, Wind: 22.3 km/h, UV: None
#  454/1000 fetched: Nangarai — 32.0°C, Wind: 7.4 km/h, UV: None
#  455/1000 fetched: SH57 — 29.4°C, Wind: 12.4 km/h, UV: None
#  456/1000 fetched: Pullampeta — 33.8°C, Wind: 12.3 km/h, UV: None
#  457/1000 fetched: kitampalayam road — 28.5°C, Wind: 8.5 km/h, UV: None
#  458/1000 fetched: Bommakkapalli — 35.4°C, Wind: 24.6 km/h, UV: None
#  459/1000 fetched: Gingee — 34.8°C, Wind: 16.1 km/h, UV: None
#  460/1000 fetched: Kushalanagar taluku — 25.3°C, Wind: 12.1 km/h, UV: None
#  461/1000 fetched: Rajupalem — 41.1°C, Wind: 14.3 km/h, UV: None
#  462/1000 fetched: Senjudaiyampalayam — 29.7°C, Wind: 12.1 km/h, UV: None
#  463/1000 fetched: Kengunte — 32.1°C, Wind: 18.0 km/h, UV: None
#  464/1000 fetched: Chittoor - Tiruttani Road — 38.7°C, Wind: 11.9 km/h, UV: None
#  465/1000 fetched: Gudalur - Sulthan Bathery Road — 23.6°C, Wind: 7.9 km/h, UV: None
#  466/1000 fetched: Sanjivapuram — 39.2°C, Wind: 24.3 km/h, UV: None
#  467/1000 fetched: Chinnasalem — 34.0°C, Wind: 17.4 km/h, UV: None
#  468/1000 fetched: Gonibidu — 29.3°C, Wind: 15.0 km/h, UV: None
#  469/1000 fetched: Sreerangarajupalem — 39.6°C, Wind: 18.5 km/h, UV: None
#  470/1000 fetched: TiruppurNorth — 29.9°C, Wind: 15.9 km/h, UV: None
#  471/1000 fetched: Kavalanahalli — 34.2°C, Wind: 25.8 km/h, UV: None
#  472/1000 fetched: Vandavasi — 37.4°C, Wind: 17.4 km/h, UV: None
#  473/1000 fetched: Haisodluru — 25.3°C, Wind: 11.4 km/h, UV: None
#  474/1000 fetched: Obulapuram — 38.8°C, Wind: 16.0 km/h, UV: None
#  475/1000 fetched: Palaiyavalavu — 26.4°C, Wind: 6.3 km/h, UV: None
#  476/1000 fetched: Chakonahalli — 31.3°C, Wind: 18.3 km/h, UV: None
#  477/1000 fetched: Malapalle — 38.4°C, Wind: 9.4 km/h, UV: None
#  478/1000 fetched: Kundah — 18.0°C, Wind: 12.9 km/h, UV: None
#  479/1000 fetched: Sollapuram — 37.6°C, Wind: 21.6 km/h, UV: None
#  480/1000 fetched: Tirukkoyilur — 33.7°C, Wind: 17.2 km/h, UV: None
#  481/1000 fetched: Heggadahalli — 25.7°C, Wind: 9.7 km/h, UV: None
#  482/1000 fetched: MDR — 40.4°C, Wind: 15.5 km/h, UV: None
#  483/1000 fetched: Kodumudi — 30.1°C, Wind: 15.2 km/h, UV: None
#  484/1000 fetched: Madakaripura — 32.2°C, Wind: 22.4 km/h, UV: None
#  485/1000 fetched: Arakonam — 38.9°C, Wind: 15.2 km/h, UV: None
#  486/1000 fetched: Kenichira — 27.4°C, Wind: 8.6 km/h, UV: None
#  487/1000 fetched: Alangarpeta — 39.0°C, Wind: 24.1 km/h, UV: None
#  488/1000 fetched: Krishnapuram - Poolambadi - Veeraganur Road — 33.2°C, Wind: 10.4 km/h, UV: None
#  489/1000 fetched: Kallappanahalli — 26.4°C, Wind: 14.8 km/h, UV: None
#  490/1000 fetched: Pullampeta — 40.5°C, Wind: 13.6 km/h, UV: None
#  491/1000 fetched: Kunnathur — 29.3°C, Wind: 12.8 km/h, UV: None
#  492/1000 fetched: SH65 — 34.1°C, Wind: 23.5 km/h, UV: None
#  493/1000 fetched: Giingee — 35.3°C, Wind: 17.4 km/h, UV: None
#  494/1000 fetched: Halugunda — 26.8°C, Wind: 14.9 km/h, UV: None
#  495/1000 fetched: Indla Siddaya Palli — 40.0°C, Wind: 14.8 km/h, UV: None
#  496/1000 fetched: Tholur — 30.1°C, Wind: 10.8 km/h, UV: None
#  497/1000 fetched: Mavinahole — 30.6°C, Wind: 18.7 km/h, UV: None
#  498/1000 fetched: Kottaindlu — 38.2°C, Wind: 11.1 km/h, UV: None
#  499/1000 fetched: Gudalur — 23.6°C, Wind: 4.8 km/h, UV: None
#  500/1000 fetched: Jarutla Rampuram — 39.2°C, Wind: 22.2 km/h, UV: None
#  501/1000 fetched: Thiyagadurgam - Adari Road — 33.7°C, Wind: 20.1 km/h, UV: None
#  502/1000 fetched: Sakaleshapura taluk — 25.0°C, Wind: 12.0 km/h, UV: None
#  503/1000 fetched: Balijapalle — 38.1°C, Wind: 12.9 km/h, UV: None
#  504/1000 fetched: Tiruppur South — 29.7°C, Wind: 19.4 km/h, UV: None
#  505/1000 fetched: Honnamaradi — 33.5°C, Wind: 23.3 km/h, UV: None
#  506/1000 fetched: Tiruvetipuram — 38.3°C, Wind: 17.5 km/h, UV: None
#  507/1000 fetched: Thirunelli — 23.1°C, Wind: 9.0 km/h, UV: None
#  508/1000 fetched: Sanagalaguduru — 40.4°C, Wind: 18.8 km/h, UV: None
#  509/1000 fetched: Venkatachalapuram — 32.4°C, Wind: 11.9 km/h, UV: None
#  510/1000 fetched: Tanigebailu — 29.8°C, Wind: 16.0 km/h, UV: None
#  511/1000 fetched: Tirupati — 36.4°C, Wind: 11.9 km/h, UV: None
#  512/1000 fetched: Muthukallur — 27.4°C, Wind: 8.6 km/h, UV: None
#  513/1000 fetched: Gollaladoddi — 36.4°C, Wind: 21.1 km/h, UV: None
#  514/1000 fetched: Kandachipuram — 34.4°C, Wind: 17.2 km/h, UV: None
#  515/1000 fetched: Madikeri taluku — 24.3°C, Wind: 11.3 km/h, UV: None
#  516/1000 fetched: Parigaripalle — 40.6°C, Wind: 20.0 km/h, UV: None
#  517/1000 fetched: Kuppampalayam — 29.9°C, Wind: 14.6 km/h, UV: None
#  518/1000 fetched: Siddanamatha — 32.3°C, Wind: 18.4 km/h, UV: None
#  519/1000 fetched: Arakonam — 38.5°C, Wind: 12.8 km/h, UV: None
#  520/1000 fetched: Pallithazham — 26.5°C, Wind: 7.2 km/h, UV: None
#  521/1000 fetched: MDR — 39.3°C, Wind: 22.0 km/h, UV: None
#  522/1000 fetched: Tittakudi — 33.2°C, Wind: 15.5 km/h, UV: None
#  523/1000 fetched: Mudigere taluk — 29.9°C, Wind: 12.0 km/h, UV: None
#  524/1000 fetched: Dalavaipalle — 40.3°C, Wind: 15.2 km/h, UV: None
#  525/1000 fetched: Palladam — 29.3°C, Wind: 19.6 km/h, UV: None
#  526/1000 fetched: Kolamatti — 34.2°C, Wind: 27.1 km/h, UV: None
#  527/1000 fetched: Vandavasi — 36.9°C, Wind: 17.7 km/h, UV: None
#  528/1000 fetched: Virajpet taluk — 27.6°C, Wind: 9.9 km/h, UV: None
#  529/1000 fetched: MDR — 38.9°C, Wind: 19.2 km/h, UV: None
#  530/1000 fetched: Keelamedu — 30.1°C, Wind: 12.7 km/h, UV: None
#  531/1000 fetched: Balekatte — 30.5°C, Wind: 15.9 km/h, UV: None
#  532/1000 fetched: NH716 — 38.2°C, Wind: 11.1 km/h, UV: None
#  533/1000 fetched: Kundah — 15.7°C, Wind: 6.6 km/h, UV: None
#  534/1000 fetched: Uravakonda — 38.2°C, Wind: 25.8 km/h, UV: None
#  535/1000 fetched: Ulundurpettai — 34.0°C, Wind: 20.2 km/h, UV: None
#  536/1000 fetched: Kombaru — 30.2°C, Wind: 7.4 km/h, UV: None
#  537/1000 fetched: Gunakanulapalle — 39.9°C, Wind: 14.6 km/h, UV: None
#  538/1000 fetched: Kangeyam — 29.7°C, Wind: 16.9 km/h, UV: None
#  539/1000 fetched: Chaulihalli — 32.5°C, Wind: 20.0 km/h, UV: None
#  540/1000 fetched: Vembakkam — 38.4°C, Wind: 17.4 km/h, UV: None
#  541/1000 fetched: Anchamail-Tharuvana Road — 27.7°C, Wind: 8.7 km/h, UV: None
#  542/1000 fetched: Tatagaripalle — 40.1°C, Wind: 21.0 km/h, UV: None
#  543/1000 fetched: Valaiyur — 28.9°C, Wind: 11.4 km/h, UV: None
#  544/1000 fetched: Chikkamagaluru taluku — 29.1°C, Wind: 12.3 km/h, UV: None
#  545/1000 fetched: Marapalle — 40.0°C, Wind: 18.5 km/h, UV: None
#  546/1000 fetched: Ward 4 — 27.9°C, Wind: 13.8 km/h, UV: None
#  547/1000 fetched: Heruru — 35.6°C, Wind: 22.7 km/h, UV: None
#  548/1000 fetched: Thirunandipuram — 35.3°C, Wind: 20.1 km/h, UV: None
#  549/1000 fetched: Yemmemadu — 25.3°C, Wind: 10.1 km/h, UV: None
#  550/1000 fetched: Sanjivareddipalle — 40.0°C, Wind: 17.7 km/h, UV: None
#  551/1000 fetched: Vadugapattipudur — 29.9°C, Wind: 15.4 km/h, UV: None
#  552/1000 fetched: Ittige — 31.9°C, Wind: 21.4 km/h, UV: None
#  553/1000 fetched: Poonimangadu Road — 39.0°C, Wind: 12.7 km/h, UV: None
#  554/1000 fetched: Nilambur — 28.4°C, Wind: 9.8 km/h, UV: None
#  555/1000 fetched: Eguvu Thanda — 39.4°C, Wind: 21.7 km/h, UV: None
#  556/1000 fetched: Periyanesalu-kalthur road — 33.8°C, Wind: 17.6 km/h, UV: None
#  557/1000 fetched: Hemmadi — 28.5°C, Wind: 9.3 km/h, UV: None
#  558/1000 fetched: Nallathimmayapalle — 38.5°C, Wind: 17.1 km/h, UV: None
#  559/1000 fetched: Palladam — 29.3°C, Wind: 20.7 km/h, UV: None
#  560/1000 fetched: Jyotipura — 33.5°C, Wind: 23.8 km/h, UV: None
#  561/1000 fetched: Kancheepuram - Vandavasi Road — 37.8°C, Wind: 17.3 km/h, UV: None
#  562/1000 fetched: Adakkathodu — 28.4°C, Wind: 7.9 km/h, UV: None
#  563/1000 fetched: Mukkabaipalle — 38.4°C, Wind: 14.3 km/h, UV: None
#  564/1000 fetched: Senappanallur — 31.7°C, Wind: 13.5 km/h, UV: None
#  565/1000 fetched: Nellisara — 31.2°C, Wind: 15.6 km/h, UV: None
#  566/1000 fetched: Dharmapuram Khandriga — 38.8°C, Wind: 10.3 km/h, UV: None
#  567/1000 fetched: Mannarkad — 27.2°C, Wind: 12.8 km/h, UV: None
#  568/1000 fetched: Sreedharaghattu — 37.5°C, Wind: 26.1 km/h, UV: None
#  569/1000 fetched: Thiruvennainallur — 34.0°C, Wind: 19.2 km/h, UV: None
#  570/1000 fetched: Sulya taluk — 28.4°C, Wind: 9.0 km/h, UV: None
#  571/1000 fetched: Khajipet — 39.5°C, Wind: 13.7 km/h, UV: None
#  572/1000 fetched: Sadachivalasu — 29.0°C, Wind: 21.0 km/h, UV: None
#  573/1000 fetched: Vaderahalli — 32.4°C, Wind: 16.5 km/h, UV: None
#  574/1000 fetched: Arakonam — 38.5°C, Wind: 16.3 km/h, UV: None
#  575/1000 fetched: Chundale — 25.6°C, Wind: 6.3 km/h, UV: None
#  576/1000 fetched: Bhimunipalli — 39.0°C, Wind: 21.7 km/h, UV: None
#  577/1000 fetched: Siruvayalur — 33.2°C, Wind: 15.0 km/h, UV: None
#  578/1000 fetched: Chikkamagaluru taluku — 29.3°C, Wind: 12.5 km/h, UV: None
#  579/1000 fetched: Nethivaripalle — 40.9°C, Wind: 16.1 km/h, UV: None
#  580/1000 fetched: Peedampalli — 27.4°C, Wind: 20.2 km/h, UV: None
#  581/1000 fetched: Shidegallu — 34.3°C, Wind: 26.7 km/h, UV: None
#  582/1000 fetched: Tindivanam — 36.2°C, Wind: 19.2 km/h, UV: None
#  583/1000 fetched: Madikeri taluku — 25.9°C, Wind: 8.1 km/h, UV: None
#  584/1000 fetched: Nemalladinne — 39.6°C, Wind: 18.2 km/h, UV: None
#  585/1000 fetched: Thottiyam - Kattuputhur Road — 31.5°C, Wind: 14.2 km/h, UV: None
#  586/1000 fetched: Shimoga - Chitradurga Highway — 31.3°C, Wind: 14.2 km/h, UV: None
#  587/1000 fetched: Lakshmivalasapuram — 39.0°C, Wind: 10.5 km/h, UV: None
#  588/1000 fetched: Nilambur — 24.8°C, Wind: 5.6 km/h, UV: None
#  589/1000 fetched: Vajrakarur — 38.0°C, Wind: 26.0 km/h, UV: None
#  590/1000 fetched: Grand Southern Trunk Road — 33.7°C, Wind: 20.2 km/h, UV: None
#  591/1000 fetched: Beltangadi taluk — 30.6°C, Wind: 11.6 km/h, UV: None
#  592/1000 fetched: Mittapalle — 40.5°C, Wind: 20.2 km/h, UV: None
#  593/1000 fetched: Uthiyur — 29.0°C, Wind: 19.6 km/h, UV: None
#  594/1000 fetched: Pallagatte — 32.9°C, Wind: 20.1 km/h, UV: None
#  595/1000 fetched: Vembakkam — 39.0°C, Wind: 17.0 km/h, UV: None
#  596/1000 fetched: Pathirimandham colony — 25.4°C, Wind: 9.9 km/h, UV: None
#  597/1000 fetched: Bandariapalle — 38.6°C, Wind: 17.3 km/h, UV: None
#  598/1000 fetched: Nagalapuram — 31.1°C, Wind: 13.3 km/h, UV: None
#  599/1000 fetched: Saluru — 30.1°C, Wind: 14.4 km/h, UV: None
#  600/1000 fetched: Kota — 40.6°C, Wind: 18.8 km/h, UV: None
#  601/1000 fetched: Coimbatore South — 26.4°C, Wind: 8.4 km/h, UV: None
#  602/1000 fetched: Kanakuppe — 36.9°C, Wind: 24.6 km/h, UV: None
#  603/1000 fetched: Orathur — 34.3°C, Wind: 18.7 km/h, UV: None
#  604/1000 fetched: Bhagamandala — 24.1°C, Wind: 10.2 km/h, UV: None
#  605/1000 fetched: Krishnapuram — 39.8°C, Wind: 16.6 km/h, UV: None
#  606/1000 fetched: T.Pasupathipalayam — 29.9°C, Wind: 17.0 km/h, UV: None
#  607/1000 fetched: Tyavanige — 32.4°C, Wind: 19.1 km/h, UV: None
#  608/1000 fetched: Tiruttani — 39.4°C, Wind: 13.6 km/h, UV: None
#  609/1000 fetched: Nilambur — 20.6°C, Wind: 5.4 km/h, UV: None
#  610/1000 fetched: Aniganidoddi — 39.8°C, Wind: 21.9 km/h, UV: None
#  611/1000 fetched: Tittakudi — 34.1°C, Wind: 19.4 km/h, UV: None
#  612/1000 fetched: Madugundi — 28.3°C, Wind: 9.8 km/h, UV: None
#  613/1000 fetched: Reniguntapalli — 39.5°C, Wind: 18.5 km/h, UV: None
#  614/1000 fetched: Odakkalpalayam — 28.7°C, Wind: 23.0 km/h, UV: None
#  615/1000 fetched: Suladahalli — 33.6°C, Wind: 23.8 km/h, UV: None
#  616/1000 fetched: Vandavasi — 36.6°C, Wind: 17.4 km/h, UV: None
#  617/1000 fetched: Iritty — 28.7°C, Wind: 9.8 km/h, UV: None
#  618/1000 fetched: A.kambaladinne — 39.1°C, Wind: 15.3 km/h, UV: None
#  619/1000 fetched: Sittitarai — 32.0°C, Wind: 15.2 km/h, UV: None
#  620/1000 fetched: Ramapura — 31.7°C, Wind: 14.2 km/h, UV: None
#  621/1000 fetched: Adavaram — 35.8°C, Wind: 12.0 km/h, UV: None
#  622/1000 fetched: Mukkali — 23.6°C, Wind: 7.7 km/h, UV: None
#  623/1000 fetched: Bellary taluk — 38.8°C, Wind: 24.4 km/h, UV: None
#  624/1000 fetched: Ulundurpettai — 34.1°C, Wind: 23.6 km/h, UV: None
#  625/1000 fetched: SH100 — 29.9°C, Wind: 12.8 km/h, UV: None
#  626/1000 fetched: Sidhout — 40.5°C, Wind: 15.6 km/h, UV: None
#  627/1000 fetched: Dharapuram — 29.5°C, Wind: 22.7 km/h, UV: None
#  628/1000 fetched: Tumbigere — 32.5°C, Wind: 18.7 km/h, UV: None
#  629/1000 fetched: Kanchipuram — 39.2°C, Wind: 16.5 km/h, UV: None
#  630/1000 fetched: Choothupara — 25.8°C, Wind: 6.3 km/h, UV: None
#  631/1000 fetched: Obulapuram — 38.7°C, Wind: 15.1 km/h, UV: None
#  632/1000 fetched: Selliyampalayam — 31.9°C, Wind: 18.4 km/h, UV: None
#  633/1000 fetched: Hunasekoppa — 28.5°C, Wind: 12.0 km/h, UV: None
#  634/1000 fetched: Althurupadu — 40.0°C, Wind: 19.1 km/h, UV: None
#  635/1000 fetched: Madukkarai — 27.7°C, Wind: 9.2 km/h, UV: None
#  636/1000 fetched: Devarlahalli — 33.9°C, Wind: 24.8 km/h, UV: None
#  637/1000 fetched: Mailam — 35.0°C, Wind: 19.2 km/h, UV: None
#  638/1000 fetched: Manakadavu — 27.3°C, Wind: 11.0 km/h, UV: None
#  639/1000 fetched: MDR — 39.5°C, Wind: 15.2 km/h, UV: None
#  640/1000 fetched: Vaiyampatty - Mylampatty - Uppidamangalam - Karur Road — 31.3°C, Wind: 14.8 km/h, UV: None
#  641/1000 fetched: Bagevadi — 32.0°C, Wind: 17.9 km/h, UV: None
#  642/1000 fetched: Siddirajukandriga — 40.1°C, Wind: 16.1 km/h, UV: None
#  643/1000 fetched: Nilambur — 28.2°C, Wind: 10.0 km/h, UV: None
#  644/1000 fetched: Donimukkala — 38.5°C, Wind: 22.2 km/h, UV: None
#  645/1000 fetched: Veppur — 34.0°C, Wind: 19.8 km/h, UV: None
#  646/1000 fetched: Kanyadi — 30.8°C, Wind: 6.4 km/h, UV: None
#  647/1000 fetched: Penagalur — 40.4°C, Wind: 21.1 km/h, UV: None
#  648/1000 fetched: Dharapuram — 28.8°C, Wind: 22.3 km/h, UV: None
#  649/1000 fetched: Kurubanahalli — 33.4°C, Wind: 20.1 km/h, UV: None
#  650/1000 fetched: Kammalampoondi — 38.5°C, Wind: 17.7 km/h, UV: None
#  651/1000 fetched: Vadakara — 23.7°C, Wind: 10.5 km/h, UV: None
#  652/1000 fetched: Ramireddypalem — 39.2°C, Wind: 17.2 km/h, UV: None
#  653/1000 fetched: Manbarai — 31.8°C, Wind: 15.7 km/h, UV: None
#  654/1000 fetched: Muttinakoppa — 30.2°C, Wind: 15.5 km/h, UV: None
#  655/1000 fetched: Akkurthi Road — 40.3°C, Wind: 15.5 km/h, UV: None
#  656/1000 fetched: Mannarkad — 23.1°C, Wind: 9.2 km/h, UV: None
#  657/1000 fetched: Mincheri — 36.7°C, Wind: 26.5 km/h, UV: None
#  658/1000 fetched: Viluppuram — 33.6°C, Wind: 23.1 km/h, UV: None
#  659/1000 fetched: Adiwasi Colony Kammadi — 28.4°C, Wind: 12.2 km/h, UV: None
#  660/1000 fetched: Brahmamgarimattam — 39.6°C, Wind: 19.6 km/h, UV: None
#  661/1000 fetched: Dharapuram — 30.2°C, Wind: 18.5 km/h, UV: None
#  662/1000 fetched: Batlakatte — 32.3°C, Wind: 17.6 km/h, UV: None
#  663/1000 fetched: Thiruvallur — 39.3°C, Wind: 16.1 km/h, UV: None
#  664/1000 fetched: Murampathy — 27.9°C, Wind: 7.9 km/h, UV: None
#  665/1000 fetched: Podadoddi — 37.4°C, Wind: 28.6 km/h, UV: None
#  666/1000 fetched: Ayeekudi — 33.0°C, Wind: 21.3 km/h, UV: None
#  667/1000 fetched: Haluvalli — 29.4°C, Wind: 11.1 km/h, UV: None
#  668/1000 fetched: Rapur — 37.0°C, Wind: 14.3 km/h, UV: None
#  669/1000 fetched: Cherippalayam — 27.0°C, Wind: 27.9 km/h, UV: None
#  670/1000 fetched: Agrahara — 33.3°C, Wind: 24.9 km/h, UV: None
#  671/1000 fetched: Tindivanam — 35.9°C, Wind: 18.2 km/h, UV: None
#  672/1000 fetched: Taliparamba — 29.3°C, Wind: 14.0 km/h, UV: None
#  673/1000 fetched: Jangalapalle — 39.3°C, Wind: 14.8 km/h, UV: None
#  674/1000 fetched: Kulanthaipatty c — 31.9°C, Wind: 13.1 km/h, UV: None
#  675/1000 fetched: Hunasodu — 31.9°C, Wind: 18.7 km/h, UV: None
#  676/1000 fetched: Varadaiahpalem — 36.7°C, Wind: 11.1 km/h, UV: None
#  677/1000 fetched: Mannarkad — 25.5°C, Wind: 8.7 km/h, UV: None
#  678/1000 fetched: Bevinhal — 39.3°C, Wind: 26.3 km/h, UV: None
#  679/1000 fetched: Virudhachalam — 33.1°C, Wind: 17.3 km/h, UV: None
#  680/1000 fetched: SH113 — 30.7°C, Wind: 11.8 km/h, UV: None
#  681/1000 fetched: Nirudrayapalle — 40.6°C, Wind: 23.4 km/h, UV: None
#  682/1000 fetched: Dharapuram — 28.7°C, Wind: 22.7 km/h, UV: None
#  683/1000 fetched: SH 47 — 33.2°C, Wind: 20.8 km/h, UV: None
#  684/1000 fetched: Tirumakkūdal — 39.0°C, Wind: 16.6 km/h, UV: None
#  685/1000 fetched: Changaroth — 28.9°C, Wind: 10.7 km/h, UV: None
#  686/1000 fetched: Isranayak Tanda — 37.9°C, Wind: 20.1 km/h, UV: None
#  687/1000 fetched: Shanamangalam — 31.6°C, Wind: 19.4 km/h, UV: None
#  688/1000 fetched: Chauki — 28.7°C, Wind: 11.5 km/h, UV: None
#  689/1000 fetched: Patrapalli — 40.5°C, Wind: 25.3 km/h, UV: None
#  690/1000 fetched: Palakkad — 27.8°C, Wind: 12.5 km/h, UV: None
#  691/1000 fetched: Timmalapura — 35.5°C, Wind: 28.0 km/h, UV: None
#  692/1000 fetched: Villianur Taluk — 34.5°C, Wind: 18.9 km/h, UV: None
#  693/1000 fetched: Malankadavu — 29.7°C, Wind: 15.3 km/h, UV: None
#  694/1000 fetched: S.Mydukur — 37.0°C, Wind: 10.9 km/h, UV: None
#  695/1000 fetched: R. Vellagoundan Patti — 29.9°C, Wind: 16.7 km/h, UV: None
#  696/1000 fetched: Arakere — 31.5°C, Wind: 18.3 km/h, UV: None
#  697/1000 fetched: Uthukkottai — 39.9°C, Wind: 16.7 km/h, UV: None
#  698/1000 fetched: Chathalloor — 27.9°C, Wind: 13.6 km/h, UV: None
#  699/1000 fetched: Ramapuram — 39.4°C, Wind: 19.3 km/h, UV: None
#  700/1000 fetched: Thalavai — 33.9°C, Wind: 18.3 km/h, UV: None
#  701/1000 fetched: Beltangadi taluk — 28.4°C, Wind: 13.3 km/h, UV: None
#  702/1000 fetched: Koturupalle — 39.5°C, Wind: 15.4 km/h, UV: None
#  703/1000 fetched: Madathukulam — 28.0°C, Wind: 24.5 km/h, UV: None
#  704/1000 fetched: Sirinayakanahalli — 34.2°C, Wind: 26.1 km/h, UV: None
#  705/1000 fetched: Cheyyur — 37.3°C, Wind: 17.7 km/h, UV: None
#  706/1000 fetched: Kaitheri — 29.6°C, Wind: 12.7 km/h, UV: None
#  707/1000 fetched: MDR — 39.6°C, Wind: 15.7 km/h, UV: None
#  708/1000 fetched: Perugamani — 32.2°C, Wind: 13.4 km/h, UV: None
#  709/1000 fetched: Shivamogga — 29.7°C, Wind: 14.8 km/h, UV: None
# ...
#  764/1000 fetched: Adagadi — 30.4°C, Wind: 16.9 km/h, UV: None
#  765/1000 fetched: Ramalingapuram — 39.8°C, Wind: 17.9 km/h, UV: None
#  766/1000 fetched: Koorakottil — 28.7°C, Wind: 10.2 km/h, UV: None
#  767/1000 fetched: Erragudi — 39.8°C, Wind: 26.6 km/h, UV: None
#  768/1000 fetched: Panruti — 33.5°C, Wind: 19.4 km/h, UV: None
#  769/1000 fetched: Saja — 29.7°C, Wind: 14.0 km/h, UV: None
#  770/1000 fetched: Chabolu — 40.0°C, Wind: 24.0 km/h, UV: None
#  771/1000 fetched: Oddanchatram — 27.6°C, Wind: 15.8 km/h, UV: None
#  772/1000 fetched: Hosapete-Harihara Road — 32.9°C, Wind: 21.7 km/h, UV: None
#  773/1000 fetched: Maraimalai Nagar — 37.9°C, Wind: 18.5 km/h, UV: None
#  774/1000 fetched: Vaidyarangadi — 28.9°C, Wind: 16.0 km/h, UV: None
#  775/1000 fetched: Kamalapuram — 38.8°C, Wind: 15.9 km/h, UV: None
#  776/1000 fetched: Vadugarpettai — 32.1°C, Wind: 14.4 km/h, UV: None
#  777/1000 fetched: Thirthahalli - Sringeri Rd. — 28.3°C, Wind: 13.3 km/h, UV: None
#  778/1000 fetched: Nernur — 41.9°C, Wind: 17.6 km/h, UV: None
#  779/1000 fetched: Chittur — 27.8°C, Wind: 22.9 km/h, UV: None
#  780/1000 fetched: Nagalapura — 36.4°C, Wind: 29.0 km/h, UV: None
#  781/1000 fetched: Victory — 33.3°C, Wind: 25.3 km/h, UV: None
#  782/1000 fetched: Purakkunnu — 29.0°C, Wind: 15.1 km/h, UV: None
#  783/1000 fetched: Jyothi — 36.9°C, Wind: 9.1 km/h, UV: None
#  784/1000 fetched: Singampatti — 30.3°C, Wind: 15.9 km/h, UV: None
#  785/1000 fetched: Guddadamadapura — 31.1°C, Wind: 19.1 km/h, UV: None
#  786/1000 fetched: Thandalam - Mukkarambakkam Road — 38.9°C, Wind: 20.9 km/h, UV: None
#  787/1000 fetched: Kolayi Waterfall — 28.0°C, Wind: 16.4 km/h, UV: None
#  788/1000 fetched: Hosur — 39.1°C, Wind: 34.9 km/h, UV: None
#  789/1000 fetched: Kombuthi — 32.7°C, Wind: 19.7 km/h, UV: None
#  790/1000 fetched: Venoor — 30.7°C, Wind: 14.5 km/h, UV: None
#  791/1000 fetched: Kachiridevarayapalle — 39.7°C, Wind: 21.1 km/h, UV: None
#  792/1000 fetched: Madathukulam — 27.8°C, Wind: 24.8 km/h, UV: None
#  793/1000 fetched: Alaburu — 34.6°C, Wind: 23.2 km/h, UV: None
#  794/1000 fetched: Cheyyur — 36.6°C, Wind: 17.6 km/h, UV: None
#  795/1000 fetched: Punnol — 29.4°C, Wind: 15.1 km/h, UV: None
#  796/1000 fetched: Kyapa — 39.6°C, Wind: 14.4 km/h, UV: None
#  797/1000 fetched: military Canteen — 32.5°C, Wind: 14.0 km/h, UV: None
#  798/1000 fetched: Konanduru — 29.5°C, Wind: 16.4 km/h, UV: None
#  799/1000 fetched: MDR — 40.4°C, Wind: 22.2 km/h, UV: None
#  800/1000 fetched: Palghat-Ottappalam-Shornur Road — 28.5°C, Wind: 15.8 km/h, UV: None
#  801/1000 fetched: Vaddatti Camp — 39.3°C, Wind: 26.0 km/h, UV: None
#  802/1000 fetched: Cuddalore — 33.4°C, Wind: 23.8 km/h, UV: None
#  803/1000 fetched: Munnad — 29.3°C, Wind: 16.3 km/h, UV: None
#  804/1000 fetched: Challagirigella — 38.4°C, Wind: 14.8 km/h, UV: None
#  805/1000 fetched: Thadikombu - Pallapatti - Aravakurichi Road — 28.3°C, Wind: 19.1 km/h, UV: None
#  806/1000 fetched: Chalageri — 32.7°C, Wind: 18.3 km/h, UV: None
#  807/1000 fetched: Chembarambakkam Dam Road — 39.0°C, Wind: 18.7 km/h, UV: None
#  808/1000 fetched: Chevarambalam Paroppady Road — 29.4°C, Wind: 17.7 km/h, UV: None
#  809/1000 fetched: Lakkasagaram Road — 37.7°C, Wind: 26.0 km/h, UV: None
#  810/1000 fetched: Panangur — 31.2°C, Wind: 14.8 km/h, UV: None
#  811/1000 fetched: Menasukodige — 27.1°C, Wind: 8.7 km/h, UV: None
#  812/1000 fetched: Daggunta — 41.1°C, Wind: 24.5 km/h, UV: None
#  813/1000 fetched: Samathur — 28.0°C, Wind: 12.8 km/h, UV: None
#  814/1000 fetched: Danayakanakere — 34.0°C, Wind: 19.1 km/h, UV: None
#  815/1000 fetched: Ekkiar Kuppam — 33.2°C, Wind: 24.9 km/h, UV: None
#  816/1000 fetched: Pilathara - Pazhayangadi - Pappinisseri — 29.1°C, Wind: 19.8 km/h, UV: None
#  817/1000 fetched: Reddipalle — 38.1°C, Wind: 14.4 km/h, UV: None
#  818/1000 fetched: Ramanampatti — 31.7°C, Wind: 13.4 km/h, UV: None
#  819/1000 fetched: Anjanapura — 30.8°C, Wind: 16.9 km/h, UV: None
#  820/1000 fetched: Mallavaripalemmitta — 38.4°C, Wind: 20.2 km/h, UV: None
#  821/1000 fetched: T.N. Puram — 28.1°C, Wind: 14.1 km/h, UV: None
#  822/1000 fetched: Alur - Holagunda - Honnur Road — 38.3°C, Wind: 31.0 km/h, UV: None
#  823/1000 fetched: Chidambaram — 33.5°C, Wind: 21.0 km/h, UV: None
#  824/1000 fetched: Iranduru — 29.6°C, Wind: 14.2 km/h, UV: None
#  825/1000 fetched: Chinna Machunuru Road — 40.5°C, Wind: 19.6 km/h, UV: None
#  826/1000 fetched: Palani — 27.5°C, Wind: 14.8 km/h, UV: None
#  827/1000 fetched: Almarshikeri — 33.3°C, Wind: 21.6 km/h, UV: None
#  828/1000 fetched: Chengalpattu — 37.4°C, Wind: 17.3 km/h, UV: None
#  829/1000 fetched: India — 29.4°C, Wind: 20.8 km/h, UV: None
#  830/1000 fetched: Ambapuram — 37.9°C, Wind: 12.3 km/h, UV: None
#  831/1000 fetched: North Street — 31.7°C, Wind: 14.0 km/h, UV: None
#  832/1000 fetched: Kalmane — 28.2°C, Wind: 14.8 km/h, UV: None
#  833/1000 fetched: Punnapovaripalem — 41.8°C, Wind: 17.1 km/h, UV: None
#  834/1000 fetched: Koduvayur — 28.9°C, Wind: 18.2 km/h, UV: None
#  835/1000 fetched: Somalapura — 37.8°C, Wind: 29.3 km/h, UV: None
#  836/1000 fetched: Pooranamkuppam — 34.0°C, Wind: 24.8 km/h, UV: None
#  837/1000 fetched: Chayoth — 29.0°C, Wind: 16.1 km/h, UV: None
#  838/1000 fetched: MDR — 39.8°C, Wind: 10.0 km/h, UV: None
#  839/1000 fetched: Vedasandur — 29.9°C, Wind: 16.5 km/h, UV: None
#  840/1000 fetched: Sannagubbi — 32.8°C, Wind: 20.2 km/h, UV: None
#  841/1000 fetched: Alamadhi — 37.9°C, Wind: 18.9 km/h, UV: None
#  842/1000 fetched: Government Lower Primary School — 28.8°C, Wind: 17.3 km/h, UV: None
#  843/1000 fetched: Pandikona — 38.4°C, Wind: 17.9 km/h, UV: None
#  844/1000 fetched: Kankeyankuruchi — 31.4°C, Wind: 17.7 km/h, UV: None
#  845/1000 fetched: Renjala — 29.5°C, Wind: 14.4 km/h, UV: None
#  846/1000 fetched: Gollapalli — 40.1°C, Wind: 12.0 km/h, UV: None
#  847/1000 fetched: Jallipatti — 27.6°C, Wind: 15.9 km/h, UV: None
#  848/1000 fetched: SH40 — 34.6°C, Wind: 22.1 km/h, UV: None
#  849/1000 fetched: East Coast Road — 33.6°C, Wind: 24.3 km/h, UV: None
#  850/1000 fetched: India — 29.5°C, Wind: 29.6 km/h, UV: None
#  851/1000 fetched: Gosapadu - Yallur Road — 39.8°C, Wind: 14.4 km/h, UV: None
#  852/1000 fetched: Fathima Nagar — 32.3°C, Wind: 13.7 km/h, UV: None
#  853/1000 fetched: Gavaturu — 29.5°C, Wind: 16.8 km/h, UV: None
#  854/1000 fetched: Sullurpeta - N.D Road — 39.7°C, Wind: 23.0 km/h, UV: None
#  855/1000 fetched: Amrita School Road — 28.6°C, Wind: 12.7 km/h, UV: None
#  856/1000 fetched: Taluru — 39.8°C, Wind: 26.3 km/h, UV: None
#  857/1000 fetched: Kurinjipadi — 33.7°C, Wind: 24.4 km/h, UV: None
#  858/1000 fetched: Kedenji — 29.2°C, Wind: 13.0 km/h, UV: None
#  859/1000 fetched: MDR — 41.0°C, Wind: 16.3 km/h, UV: None
#  860/1000 fetched: Patchalur- Vadakadu - Oddanchatram Road — 27.7°C, Wind: 15.9 km/h, UV: None
#  861/1000 fetched: Belura — 33.4°C, Wind: 21.9 km/h, UV: None
#  862/1000 fetched: Agaramthen - Kovilanchery Road — 36.9°C, Wind: 21.5 km/h, UV: None
#  863/1000 fetched: Kozhikode — 29.4°C, Wind: 33.2 km/h, UV: None
#  864/1000 fetched: NH44 — 38.7°C, Wind: 17.3 km/h, UV: None
#  865/1000 fetched: Aarkadu — 31.4°C, Wind: 17.7 km/h, UV: None
#  866/1000 fetched: Someshwara — 29.7°C, Wind: 11.9 km/h, UV: None
#  867/1000 fetched: Lingareddipalli — 41.6°C, Wind: 16.0 km/h, UV: None
#  868/1000 fetched: Valparai — 28.3°C, Wind: 11.4 km/h, UV: None
#  869/1000 fetched: Vadrahalli — 33.9°C, Wind: 23.7 km/h, UV: None
#  870/1000 fetched: Kottakuppam — 31.5°C, Wind: 42.2 km/h, UV: None
#  871/1000 fetched: Naval Academy Road — 29.0°C, Wind: 20.6 km/h, UV: None
#  872/1000 fetched: Giddalur — 35.0°C, Wind: 15.7 km/h, UV: None
#  873/1000 fetched: Therku Ammapettai — 31.0°C, Wind: 12.9 km/h, UV: None
#  874/1000 fetched: Apinakatte — 31.1°C, Wind: 18.7 km/h, UV: None
#  875/1000 fetched: Gummidipundi — 38.4°C, Wind: 23.8 km/h, UV: None
#  876/1000 fetched: Otukkangal Rd — 28.5°C, Wind: 15.1 km/h, UV: None
#  877/1000 fetched: Chigeli — 40.1°C, Wind: 37.5 km/h, UV: None
#  878/1000 fetched: Kattumannarkoil — 33.2°C, Wind: 19.1 km/h, UV: None
#  879/1000 fetched: Badaga Belluru — 30.3°C, Wind: 13.5 km/h, UV: None
#  880/1000 fetched: Gandlavedu — 39.4°C, Wind: 24.1 km/h, UV: None
#  881/1000 fetched: Kuppampalayam — 28.1°C, Wind: 8.2 km/h, UV: None
#  882/1000 fetched: Sogi — 33.1°C, Wind: 22.9 km/h, UV: None
#  883/1000 fetched: Nathavedu — 33.7°C, Wind: 26.9 km/h, UV: None
#  884/1000 fetched: India — 29.5°C, Wind: 35.9 km/h, UV: None
#  885/1000 fetched: Palkur — 39.2°C, Wind: 15.6 km/h, UV: None
#  886/1000 fetched: NH83 Tiruchi Semicircular Ring Road — 32.3°C, Wind: 12.4 km/h, UV: None
#  887/1000 fetched: Togare — 28.6°C, Wind: 14.2 km/h, UV: None
#  888/1000 fetched: MDR — 40.6°C, Wind: 18.5 km/h, UV: None
#  889/1000 fetched: edathil colony — 29.3°C, Wind: 16.6 km/h, UV: None
#  890/1000 fetched: Virapura — 39.1°C, Wind: 33.0 km/h, UV: None
#  891/1000 fetched: Cuddalore — 33.2°C, Wind: 27.7 km/h, UV: None
#  892/1000 fetched: Makkam Veedu Bhagavathi Temple — 29.0°C, Wind: 16.6 km/h, UV: None
#  893/1000 fetched: Chandra Sekhara Puram — 36.0°C, Wind: 12.1 km/h, UV: None
#  894/1000 fetched: Thadikombu — 29.6°C, Wind: 19.2 km/h, UV: None
#  895/1000 fetched: Lakshmapura — 31.7°C, Wind: 22.8 km/h, UV: None
#  896/1000 fetched: CMWSSB Division 95 — 36.1°C, Wind: 22.6 km/h, UV: None
#  897/1000 fetched: Beypore — 29.3°C, Wind: 19.1 km/h, UV: None
#  898/1000 fetched: Gundlakonda — 38.2°C, Wind: 27.0 km/h, UV: None
#  899/1000 fetched: Arankottai — 31.7°C, Wind: 15.9 km/h, UV: None
#  900/1000 fetched: Mururu — 30.1°C, Wind: 17.1 km/h, UV: None
#  901/1000 fetched: MDR — 41.4°C, Wind: 18.6 km/h, UV: None
#  902/1000 fetched: Valparai — 27.3°C, Wind: 10.7 km/h, UV: None
#  903/1000 fetched: Nakaralu Tanda — 34.6°C, Wind: 22.1 km/h, UV: None
#  904/1000 fetched: India — 31.5°C, Wind: 39.8 km/h, UV: None
#  905/1000 fetched: India — 29.5°C, Wind: 34.0 km/h, UV: None
#  906/1000 fetched: Yellavathula — 38.4°C, Wind: 13.9 km/h, UV: None
#  907/1000 fetched: Vadakaattupatti — 32.2°C, Wind: 12.6 km/h, UV: None
#  908/1000 fetched: Kannuru Inam — 30.7°C, Wind: 16.3 km/h, UV: None
#  909/1000 fetched: Venadu — 37.5°C, Wind: 26.9 km/h, UV: None
#  910/1000 fetched: Talappilly — 28.9°C, Wind: 15.7 km/h, UV: None
#  911/1000 fetched: Lingadahalli — 39.0°C, Wind: 31.7 km/h, UV: None
#  912/1000 fetched: Chidambaram — 33.5°C, Wind: 21.7 km/h, UV: None
#  913/1000 fetched: Manjeswaram — 29.3°C, Wind: 15.8 km/h, UV: None
#  914/1000 fetched: MDR — 40.9°C, Wind: 13.1 km/h, UV: None
#  915/1000 fetched: Kodaikanal — 23.4°C, Wind: 9.7 km/h, UV: None
#  916/1000 fetched: Virapura — 33.9°C, Wind: 23.9 km/h, UV: None
#  917/1000 fetched: Vadanemmeli — 35.0°C, Wind: 21.5 km/h, UV: None
#  918/1000 fetched: India — 30.0°C, Wind: 36.2 km/h, UV: None
#  919/1000 fetched: Pendakal — 37.3°C, Wind: 16.2 km/h, UV: None
#  920/1000 fetched: P Kalivirayanpettai — 31.5°C, Wind: 20.0 km/h, UV: None
#  921/1000 fetched: Amasebylu — 29.7°C, Wind: 12.6 km/h, UV: None
#  922/1000 fetched: Kattuvapalle — 41.1°C, Wind: 18.8 km/h, UV: None
#  923/1000 fetched: Kailas Plantations — 23.6°C, Wind: 10.4 km/h, UV: None
#  924/1000 fetched: SH49 — 37.5°C, Wind: 29.5 km/h, UV: None
#  925/1000 fetched: India — 31.5°C, Wind: 46.1 km/h, UV: None
#  926/1000 fetched: Kalikadavu — 29.2°C, Wind: 17.0 km/h, UV: None
#  927/1000 fetched: Gurtapalle — 36.7°C, Wind: 16.6 km/h, UV: None
#  928/1000 fetched: Vedasandur — 29.1°C, Wind: 13.8 km/h, UV: None
#  929/1000 fetched: Hirekeruru — 31.3°C, Wind: 20.8 km/h, UV: None
#  930/1000 fetched: Elavampedu - Thiruvellavoyal Road — 38.3°C, Wind: 18.6 km/h, UV: None
#  931/1000 fetched: Vattathani — 29.2°C, Wind: 20.3 km/h, UV: None
#  932/1000 fetched: Billekal - Yemmiganur Road — 39.5°C, Wind: 33.0 km/h, UV: None
#  933/1000 fetched: North street — 32.1°C, Wind: 17.7 km/h, UV: None
#  934/1000 fetched: Kallamundukur — 29.5°C, Wind: 15.6 km/h, UV: None
#  935/1000 fetched: Atmakur - Hasanapuram Road — 39.9°C, Wind: 25.6 km/h, UV: None
#  936/1000 fetched: Udumalaipettai — 28.0°C, Wind: 14.1 km/h, UV: None
#  937/1000 fetched: Bannikallu — 34.5°C, Wind: 22.6 km/h, UV: None
#  938/1000 fetched: India — 33.4°C, Wind: 28.8 km/h, UV: None
#  939/1000 fetched: India — 29.4°C, Wind: 32.1 km/h, UV: None
#  940/1000 fetched: Kavuluru — 39.5°C, Wind: 14.2 km/h, UV: None
#  941/1000 fetched: Kulanarippatti — 32.1°C, Wind: 18.6 km/h, UV: None
#  942/1000 fetched: Punaje — 29.7°C, Wind: 17.2 km/h, UV: None
#  943/1000 fetched: Buradagalli — 38.1°C, Wind: 23.5 km/h, UV: None
#  944/1000 fetched: Talappilly — 28.7°C, Wind: 15.0 km/h, UV: None
#  945/1000 fetched: Tekkalakote — 39.7°C, Wind: 29.0 km/h, UV: None
#  946/1000 fetched: South Arcot — 32.0°C, Wind: 37.6 km/h, UV: None
#  947/1000 fetched: Siraj Nagar — 29.2°C, Wind: 16.1 km/h, UV: None
#  948/1000 fetched: Pappulavaripalle — 40.4°C, Wind: 12.9 km/h, UV: None
#  949/1000 fetched: SH 37 u/c — 29.1°C, Wind: 12.7 km/h, UV: None
#  950/1000 fetched: Hanumapura — 32.6°C, Wind: 21.8 km/h, UV: None
#  951/1000 fetched: Kottivakkam — 37.9°C, Wind: 20.1 km/h, UV: None
#  952/1000 fetched: India — 30.0°C, Wind: 35.9 km/h, UV: None
#  953/1000 fetched: Kottapalli — 39.8°C, Wind: 17.7 km/h, UV: None
#  954/1000 fetched: Sitharkadu — 31.9°C, Wind: 21.3 km/h, UV: None
#  955/1000 fetched: Udupi taluku — 30.3°C, Wind: 13.9 km/h, UV: None
#  956/1000 fetched: Donthali — 42.0°C, Wind: 20.3 km/h, UV: None
#  957/1000 fetched: Valparai — 23.7°C, Wind: 11.6 km/h, UV: None
#  958/1000 fetched: Hitnala — 34.0°C, Wind: 23.7 km/h, UV: None
#  959/1000 fetched: India — 31.4°C, Wind: 45.8 km/h, UV: None
#  960/1000 fetched: India — 29.8°C, Wind: 35.4 km/h, UV: None
#  961/1000 fetched: Rudravaram — 35.3°C, Wind: 12.3 km/h, UV: None
#  962/1000 fetched: Vilavuranipatti — 31.8°C, Wind: 13.0 km/h, UV: None
#  963/1000 fetched: Indihalli — 31.1°C, Wind: 18.7 km/h, UV: None
#  964/1000 fetched: Tada — 32.5°C, Wind: 34.8 km/h, UV: None
#  965/1000 fetched: Kumaranellur — 29.0°C, Wind: 16.9 km/h, UV: None
#  966/1000 fetched: Amaravathi Nagar — 39.0°C, Wind: 21.6 km/h, UV: None
#  967/1000 fetched: Sottariyam — 33.6°C, Wind: 15.8 km/h, UV: None
#  968/1000 fetched: Senarahithlu — 29.4°C, Wind: 18.2 km/h, UV: None
#  969/1000 fetched: NH167BG — 40.0°C, Wind: 18.6 km/h, UV: None
#  970/1000 fetched: Pallangi — 22.2°C, Wind: 9.5 km/h, UV: None
#  971/1000 fetched: Handiganura — 32.9°C, Wind: 20.0 km/h, UV: None
#  972/1000 fetched: India — 31.8°C, Wind: 38.3 km/h, UV: None
#  973/1000 fetched: India — 29.8°C, Wind: 34.3 km/h, UV: None
#  974/1000 fetched: Panyam — 38.2°C, Wind: 17.5 km/h, UV: None
#  975/1000 fetched: Kunnandarkoil - Sengipatti Road — 30.6°C, Wind: 14.7 km/h, UV: None
#  976/1000 fetched: Hosanagara taluk — 27.5°C, Wind: 13.9 km/h, UV: None
#  977/1000 fetched: MDR — 37.5°C, Wind: 20.8 km/h, UV: None
#  978/1000 fetched: Alathur — 28.8°C, Wind: 11.8 km/h, UV: None
#  979/1000 fetched: Baraguru — 40.3°C, Wind: 24.5 km/h, UV: None
#  980/1000 fetched: Unknown — 31.4°C, Wind: 39.3 km/h, UV: None
#  981/1000 fetched: India — 29.4°C, Wind: 29.9 km/h, UV: None
#  982/1000 fetched: Tekulapenta — 36.0°C, Wind: 17.1 km/h, UV: None
#  983/1000 fetched: Dindigul — 29.2°C, Wind: 12.6 km/h, UV: None
#  984/1000 fetched: Hirekeruru taluk — 31.3°C, Wind: 20.6 km/h, UV: None
#  985/1000 fetched: Ernavur Gate — 36.8°C, Wind: 21.7 km/h, UV: None
#  986/1000 fetched: India — 30.0°C, Wind: 33.1 km/h, UV: None
#  987/1000 fetched: Neruduppala — 39.5°C, Wind: 27.5 km/h, UV: None
#  988/1000 fetched: Kumbakonam — 32.3°C, Wind: 15.3 km/h, UV: None
#  989/1000 fetched: SH67 — 29.5°C, Wind: 18.6 km/h, UV: None
#  990/1000 fetched: Tarunavayl — 41.0°C, Wind: 20.3 km/h, UV: None
#  991/1000 fetched: Devikulam — 19.2°C, Wind: 9.0 km/h, UV: None
#  992/1000 fetched: Belura — 34.8°C, Wind: 21.9 km/h, UV: None
#  993/1000 fetched: India — 31.3°C, Wind: 38.5 km/h, UV: None
#  994/1000 fetched: India — 29.3°C, Wind: 32.7 km/h, UV: None
#  995/1000 fetched: Dwarakanagaram — 39.0°C, Wind: 13.7 km/h, UV: None
#  996/1000 fetched: Solacheripatti — 31.7°C, Wind: 9.7 km/h, UV: None
#  997/1000 fetched: Heggodu — 29.4°C, Wind: 19.1 km/h, UV: None
#  998/1000 fetched: SPROB Road — 37.5°C, Wind: 26.5 km/h, UV: None
#  999/1000 fetched: Thiruthiparambu — 29.0°C, Wind: 14.6 km/h, UV: None
#  1000/1000 fetched: Raravi — 41.3°C, Wind: 35.9 km/h, UV: None

# %%
df = pd.DataFrame(weather_data)
print(f"DataFrame created with {len(df)} rows.")
df.head()
# Out:
# DataFrame created with 10 rows.
#    Latitude  Longitude                       Location  Max Temp (°C)  \
# 0  12.97185   77.59470             Vittal Mallya Road           29.8
# 1  12.91002   77.48120          Bangalore-Mysore Road           31.0
# 2  12.73739   77.24689    Bengaluru-Mysuru Expressway           30.8
# 3  12.54619   76.92915    Bengaluru-Mysuru Expressway           31.9
# 4  12.35963   76.66202  Bangalore - Mysore Expressway           30.7
#
#    Min Temp (°C)  Precipitation (mm)  Wind (km/h) UV Index  Weather Code
# 0           21.7                 3.5         16.0     None            55
# 1           22.3                 2.9         12.6     None            53
# 2           22.9                 7.1         16.8     None            63
# 3           22.9                16.5         15.8     None            65
# 4           22.2                 1.2         19.9     None            51

# %% [markdown]
# ## Create Weather DataFrame

# %%
# Filter for places with Max Temp below 25°C
cool_places = df[df["Max Temp (°C)"] < 25].reset_index(drop=True)

print(f" Found {len(cool_places)} cool places with temp < 25°C")
cool_places[["Location", "Max Temp (°C)", "Precipitation (mm)", "Wind (km/h)"]]
# Out:
#  Found 24 cool places with temp < 25°C
#                           Location  Max Temp (°C)  Precipitation (mm)  \
# 0                        Thalavadi           24.4                 5.6
# 1                        Bandipura           24.9                10.6
# 2                       Kadasholai           22.2                14.3
# 3                        Benthatty           24.7                10.4
# 4                          Gudalur           24.4                14.1
# 5        Coonoor - Kattabettu Road           18.6                 9.9
# 6                           Pykara           17.7                 9.0
# 7   Gudalur - Sulthan Bathery Road           23.6                18.2
# 8                           Kundah           18.0                10.7
# 9                          Gudalur           23.6                14.6
# 10                      Thirunelli           23.1                18.1
# 11                 Madikeri taluku           24.3                13.9
# 12                          Kundah           15.7                15.6
# 13                        Nilambur           24.8                37.5
# 14                    Bhagamandala           24.1                 7.1
# 15                        Nilambur           20.6                20.2
# 16                         Mukkali           23.6                32.6
# 17                        Vadakara           23.7                18.6
# 18                       Mannarkad           23.1                38.6
# 19                      Kodaikanal           23.4                31.8
# 20              Kailas Plantations           23.6                43.1
# 21                        Valparai           23.7                28.2
# 22                        Pallangi           22.2                37.7
# 23                       Devikulam           19.2                25.6
#
#     Wind (km/h)
# 0          14.0
# 1          11.1
# 2           9.6
# 3           7.9
# 4           9.8
# 5          12.8
# 6           9.4
# 7           7.9
# 8          12.9
# 9           4.8
# 10          9.0
# 11         11.3
# 12          6.6
# 13          5.6
# 14         10.2
# 15          5.4
# 16          7.7
# 17         10.5
# 18          9.2
# 19          9.7
# 20         10.4
# 21         11.6
# 22          9.5
# 23          9.0

# %%
cool_places_sorted = cool_places.sort_values(by="Max Temp (°C)", ascending=False).reset_index(drop=True)

cool_places_sorted[["Location", "Max Temp (°C)", "Precipitation (mm)", "Wind (km/h)"]].head(19)
# Out:
#                           Location  Max Temp (°C)  Precipitation (mm)  \
# 0                        Bandipura           24.9                10.6
# 1                         Nilambur           24.8                37.5
# 2                        Benthatty           24.7                10.4
# 3                        Thalavadi           24.4                 5.6
# 4                          Gudalur           24.4                14.1
# 5                  Madikeri taluku           24.3                13.9
# 6                     Bhagamandala           24.1                 7.1
# 7                         Vadakara           23.7                18.6
# 8                         Valparai           23.7                28.2
# 9                          Mukkali           23.6                32.6
# 10                         Gudalur           23.6                14.6
# 11              Kailas Plantations           23.6                43.1
# 12  Gudalur - Sulthan Bathery Road           23.6                18.2
# 13                      Kodaikanal           23.4                31.8
# 14                      Thirunelli           23.1                18.1
# 15                       Mannarkad           23.1                38.6
# 16                        Pallangi           22.2                37.7
# 17                      Kadasholai           22.2                14.3
# 18                        Nilambur           20.6                20.2
#
#     Wind (km/h)
# 0          11.1
# 1           5.6
# 2           7.9
# 3          14.0
# 4           9.8
# 5          11.3
# 6          10.2
# 7          10.5
# 8          11.6
# 9           7.7
# 10          4.8
# 11         10.4
# 12          7.9
# 13          9.7
# 14          9.0
# 15          9.2
# 16          9.5
# 17          9.6
# 18          5.4

# %%
moderate_rain_spots = cool_places_sorted[
    (cool_places_sorted["Precipitation (mm)"] > 0) &
    (cool_places_sorted["Precipitation (mm)"] <= 15)
].reset_index(drop=True)

print(f" Found {len(moderate_rain_spots)} cool places with moderate rain.")
# Out:
#  Found 11 cool places with moderate rain.

# %%
moderate_rain_spots[["Location", "Max Temp (°C)", "Precipitation (mm)", "Wind (km/h)"]]
# Out:
#                      Location  Max Temp (°C)  Precipitation (mm)  Wind (km/h)
# 0                   Bandipura           24.9                10.6         11.1
# 1                   Benthatty           24.7                10.4          7.9
# 2                   Thalavadi           24.4                 5.6         14.0
# 3                     Gudalur           24.4                14.1          9.8
# 4             Madikeri taluku           24.3                13.9         11.3
# 5                Bhagamandala           24.1                 7.1         10.2
# 6                     Gudalur           23.6                14.6          4.8
# 7                  Kadasholai           22.2                14.3          9.6
# 8   Coonoor - Kattabettu Road           18.6                 9.9         12.8
# 9                      Kundah           18.0                10.7         12.9
# 10                     Pykara           17.7                 9.0          9.4

# %% [markdown]
# ## Find Tourist Attractions Nearby

# %%
opentrip_api_key = "ENTER-YOUR-API-KEY"

# %%
def get_nearby_attractions(lat, lon, radius=10000, limit=5):
    try:
        # Get list of places within radius
        places_url = (
            f"https://api.opentripmap.com/0.1/en/places/radius?"
            f"radius={radius}&lon={lon}&lat={lat}"
            f"&rate=2&format=json&limit={limit}&apikey={opentrip_api_key}"
        )
        response = requests.get(places_url)
        response.raise_for_status()
        places_data = response.json()

        # Fetch names of each place
        names = [place["name"] for place in places_data if place.get("name")]
        return ", ".join(names) if names else "No major attractions nearby"

    except Exception as e:
        print(f" Error fetching attractions for ({lat}, {lon}): {e}")
        return "Attractions unavailable"

# %%
attractions = []

for idx, row in moderate_rain_spots.iterrows():
    lat, lon = row["Latitude"], row["Longitude"]
    nearby = get_nearby_attractions(lat, lon)
    attractions.append(nearby)
    print(f"{idx+1}/{len(moderate_rain_spots)} — {row['Location']} → {nearby}")
    time.sleep(1)  

moderate_rain_spots["Nearby Attractions"] = attractions
# Out:
# 1/11 — Bandipura → No major attractions nearby
# 2/11 — Benthatty → No major attractions nearby
# 3/11 — Thalavadi → No major attractions nearby
# 4/11 — Gudalur → Mudumalai National Park/Tiger Reserve, Nilgiri Biosphere Reserve
# 5/11 — Madikeri taluku → Abbey Falls, Pushpagiri WLS
# 6/11 — Bhagamandala → Brahmagiri, Talakaveri WLS, Devaragundi
# 7/11 — Gudalur → No major attractions nearby
# 8/11 — Kadasholai → Kodanadu View Point
# 9/11 — Coonoor - Kattabettu Road → Sim's Park, Coonoor, Catherine Falls - Geddhehaada Halla, Wellington, Dolphin's nose, Nilgiri Mountain Railway
# 10/11 — Kundah → Katary Falls, Lovedale, Deer Park, Ooty, Ketti Mountain Railway Staion, ooty
# 11/11 — Pykara → Pykara reservoir

# %%
#  Filter for locations with real attractions
has_attractions = moderate_rain_spots[
    moderate_rain_spots["Nearby Attractions"] != "No major attractions nearby"
].reset_index(drop=True)

print(f" Found {len(has_attractions)} places with real attractions.\n")

#  Print all location names with their attractions
for idx, row in has_attractions.iterrows():
    print(f"{idx+1}. {row['Location']} → {row['Nearby Attractions']}")
# Out:
#  Found 7 places with real attractions.
#
# 1. Gudalur → Mudumalai National Park/Tiger Reserve, Nilgiri Biosphere Reserve
# 2. Madikeri taluku → Abbey Falls, Pushpagiri WLS
# 3. Bhagamandala → Brahmagiri, Talakaveri WLS, Devaragundi
# 4. Kadasholai → Kodanadu View Point
# 5. Coonoor - Kattabettu Road → Sim's Park, Coonoor, Catherine Falls - Geddhehaada Halla, Wellington, Dolphin's nose, Nilgiri Mountain Railway
# 6. Kundah → Katary Falls, Lovedale, Deer Park, Ooty, Ketti Mountain Railway Staion, ooty
# 7. Pykara → Pykara reservoir

# %%
pip install polyline
# Out:
# Collecting polylineNote: you may need to restart the kernel to use updated packages.
#
#   Downloading polyline-2.0.2-py3-none-any.whl.metadata (6.4 kB)
# Downloading polyline-2.0.2-py3-none-any.whl (6.0 kB)
# Installing collected packages: polyline
# Successfully installed polyline-2.0.2

# %%
ors_key = "5b3ce3597851110001cf6248185acb16f02148c69e3283a4451dbf58"
coordinates = [[77.5946, 12.9716], [75.7394, 12.4306]]  # [lon, lat] for ORS

url = "https://api.openrouteservice.org/v2/directions/driving-car"
headers = {
    "Authorization": ors_key,
    "Content-Type": "application/json"
}

body = {
    "coordinates": coordinates,
    "instructions": False,
    "geometry": True
}

response = requests.post(url, json=body, headers=headers)

print("Status Code:", response.status_code)
print("Raw Response:", response.text)

# Only parse JSON if response is OK
if response.status_code == 200:
    route = response.json()
else:
    print("Failed to fetch route. Check API key, URL, or quota.")
    route = None
# Out:
# Status Code: 200
# Raw Response: {"bbox":[75.739182,12.30819,77.594944,12.972022],"routes":[{"summary":{"distance":253741.8,"duration":11479.6},"bbox":[75.739182,12.30819,77.594944,12.972022],"geometry":"aqdnA{erxMa@xAFXHHJJNDHCpEk@tIkAxAOnDg@`AKb@\\HV?LuAdBYd@Uf@I^c@|CUbCCn@JjBl@`DBHLlADd@JzA@NFn@P`Ab@bA`B~AfBvAbCpB`@V\\V~CnClBbBZl@Lh@Fz@RhBHt@PvBLtBJjAAfAAXW|EOdDApA@dDIhAG\\q@`CMj@SlAWbAkApDI^Ir@@d@Fv@H^hA~ZLfAP|@^xAXhAtAjEP`@z@~ClBrJfBvHd@bCF^LxHFbAx@fF\\tC^tBl@tAV^FJRXPXh@z@lAbCv@r@|CfBd@d@^d@Vf@Pt@bAhEd@vBl@zCDPrApGTrD`@~DFb@Db@@LFh@JlAV|BTz@b@dAPd@lA`Cn@`Ad@t@~CrDHJfA|AZz@Jf@DNFXThAl@jAp@|@R\\dAfA`@b@\\d@jBvDXb@xAfCJLR`@Ph@RdAFRTj@JPz@dAxAfBp@v@~@z@p@t@`@l@PXZh@n@rAFNd@n@h@lAb@~@^hARz@Ll@Jh@Fd@nAxFdAhDvCrId@bA`AhBh@t@r@x@fC`C|ErDPJ~@l@NJv@f@hFlDh@ZvAz@l@d@p@h@\\Z~@r@rBnBDF|@bBd@v@BBPVl@`ApBtBxAvAR`@\\l@vAhHL`BBxC@t@@|AHlA^tF\\jCXtAPz@ThAHl@BL?BDR?@d@bCh@tBN^Zv@pD~EzCzDpBvBpFlJf@n@NLpAj@~BdAr@f@NVXh@JZLXd@tBj@rB`@j@n@p@nC`CtAdBzB`DhBzCFJV^xCrD~A|ALNvB`CvBrBt@x@^j@RZl@zBd@zADJxAhDj@pARf@Xp@x@rAp@l@~@f@rA|@zApA`BzBhBjBvDbBtAj@lDrC`AdAnApBhB~C\\r@h@z@x@`A|A|AXTLJdBbBbCzBn@r@`@\\l@ZVFjB`@jB`@nAZ`@VTRV^F^LjA?b@AbA?zAAl@A`AR`Al@zB^vAZlAT@TL^b@l@hBt@xCRz@Lx@h@vB@VL`@JRDRxChFh@hAPh@Lt@f@vEh@~Aj@dArA`B~@tAjAxB~A`Cf@b@h@\\dAf@lAh@`DbBf@XjA|@p@p@TVRXxDbHdDrGzI|NTb@hDxF`ApAz@|@~ArAvS|NfAdAl@t@\\d@|EdJ~AjC~A~BrC|DlApAn@h@t\\rVxAbAdAj@xQhJjMzG|EnCnAv@dBxAhBfBj@p@h@n@rHrK|@pAn@v@nAjAx@j@z@b@|@`@tA`@~IxCtJzC~BdAnAx@tB`BzApAx@l@bGxEjDtCbBhAvB|AtFtE`BhA|BtAbB`BbC~CnB`C|B|CfBfBnBxA`C|AnCpAlBr@~ExAlBp@hCbA|DnBtFjCtVlInLdDnAf@tC`B`At@`X|UfDxCjAt@vAr@j@ZhZ~L|A`@tAZhARjAN`Gb@zDd@nNhCbKfBjCb@`I|@pATvBl@fA`@t@\\lAr@`ClBdAhAt@bA~@`B`AtC^bBVdBJvAFrCv@rf@@t@\\xU@d@V|NJdDXlD`@pCfAtFlAdEnApDlAnCvAfCbAbBbB|BxAdBl@t@z@x@v[dYtOvMjBnA`@X`FhCzCpAdEvA|GzAfDd@~CVbBHbFJjGD`DAfC?L?~EB|ID`W@tAFfBTv@NhAZtAb@fAh@|A|@fDhCp@j@tJbIx@t@r@x@hAzAnA~BtHdQlAtCjAfCtC|GjF~Nr@xAdArBzLxSdAjBt@zAJRXl@v@lBj@zAh@fBjAlE`@lB^pB\\|BXdDx@jM~@dMLbBzArUzAzQN~@\\rAzCdK\\`Af@dAd@v@f@p@vOpQdAdAzSvRxLtKv@t@|AbB~JlNT\\zDbGpA`B|@|@pAbAdAt@jXpQv@h@hClBbCxBx@z@jBzB|A|BlAnBd@|@j@jAd@fAb@hAb@tAbArDTfAnZreBNnAJ`BLjC@tA?z@CfAIjAMlAO|@s@bDoFvQ{@tCmHlVM^}f@zaBc@jB_@tBQxAQbCIlB?fBDtBXnELtARjAXpA^rAd@vAh@vAh@jAlAtBj@x@nBdCrBtBr@j@jVrQpc@jZZVbAv@`CzBxx@z`AdAhAz@t@lChB~b@hWnk@r\\fEnCx\\bSrCzAxd@`TLFnKdGxBdBd^d]r@v@l@p@jBlCpPhXt@fAp@~@v@~@z@|@bA|@v@l@fAr@tUhM|BxAhBrAdAz@vBlBbQxPnCtC|NlP~C`D`KrJnBdB|@p@rAx@t@`@hAd@pAd@jBh@nAVvIvA~C`@rATxCn@tBn@|Bz@fCnAdBbAzAdAlB`BtApAzAhBvAlBtA~BfB|DpKlYdAbC`@n@j@z@z@`A~@v@x@l@~@f@tAj@dAXjAVnANfHb@lDN`Jf@zCV`BVhBf@dAb@hAf@nBlA|@t@l@p@rAbBz@vAf@fAd@tAl@~B\\jC`@bF|A|NH~@RzBXxEFrDPxORjDh@lCvArGf@pB`ArCfAxCl@xBf@xBp@pDr@|ERjBLnBFrBJdIF`BFvAPjBjBxPRrAx@hEnD~Pn@fDVbBLpAD`ADhIDxBRbE`@rDlDdYDRjDlY\\nB|@hEhArEf@zAl@zAr@tA|\\zn@bAxBnA`D\\dB\\rDH`FRjFZ|Cb@lCDR`@`CpB~HbPn]bChFjEfJlCzDfLjOdHxJfBjD|FnMzA|BxBjCtEhElCvBjA~@rH|FrF~Enn@nh@|GzHhC~EbA|CxBzJtCbN`FvWxAvHj@zCdIt`@nCxMhBjJfAbEdAjBjD`F\\^nKfOfEvFfBhCjCnDrHzJnEpFfFdG|CxDfGjH~@pAl@~@x@pBX~@vA~En@`CtA`HZlBNpAZrCP|@Pr@t@tBzA`E~AnEhChJrCnLfAlDlEdNn@bBbAfDv@~BrD|JVj@bJpUTl@r@pBvHbSxGpRj@lBb@fB\\xBPnAJtAJlBLvJ?TJpCJvANdAd@lBfAtCdJpT`F~L`BjE`GzN`KrWHRrGtPtC|GlEzJXx@j@rA|EpKrCrGHRnBrE`HjMtA|CzEnJ~BnEbJpPr@|AdE|JbFpNz@tCb@pBzAbGbA|E|@jFF|@BnBEfCIdGS~G?v@DdAIhCDhAC`CAVGnAQxAk@~BuBnHkBdISpAMtA@~A`@fLzAlQdA|IhArKHr@h@bGNvICbAQ|Bc@pD}AjJyAvJ_@tFAn@?VApANrCn@pEnCvNl@tDh@|DBRLx@l@|IpJxlBR`ELfCF~B?lFIfFg@bHc@tDw@zEEVk@zDu@zCk@zCi@nDYpC]zEIxBItKRtGl@|Gb@nDn@|DpArFhBvF|AbEjF~J^h@^f@vApBpEbFbFdFxAhAxDfCXPtC`BrDfBrFzBtBn@rDbAjHzA~Ft@XBdHj@nTtAjEf@pBT\\DdG~@VFtM~BtEzAj@XhDnBxBpBd@f@|@|@xAtB|AdD|BdFjE`LhDzJDN`BdFNl@HVdJ~]xBrIbEbP|@zC|CpJHVnIvWHVTr@bHzPrKdWHTfCbGVj@zBrF~AxDdBbEvCdH^hA^|AVtAPnADf@PxD@`@TzFJzAPzAVrAZpAh@|AjDpHd@nAn@zB^|BNrARrDzA~^b@~FDb@j@`H|Fdp@r@vIb@xCn@vC|@vCrM~[jEnKp@tAx@pArAjBn@p@nChCxBzAhHvEh@`@r@n@xAhBjBdDrFxMRb@r@`B~BvEhN|VvKdQhOnVhCxC|a@nh@h@z@NV~@dBj@nAzDzKfAlCbLbUpB~CrA`BjAlAdBnAnAt@rAr@pBz@d\\|LdCfAzBpAfA|@xA|AfAxAjCzDfA|A~@bAz@x@jAn@vL~F|BrAbUvRXTbAhA`DpE`F|H~BxDbCzDdAzAr@fBf@jB^bBz@zF^~A`@jAj@xA`AjAj@v@hAvAjA`AhDlClZpVnQzNzDhDjDfDnGtHt@z@bR` ...

# %%
# GraphHopper API setup
gh_key = "ENTER-YOUR-API-KEY"  
url = "https://graphhopper.com/api/1/route"

# Start: Bangalore (77.5946, 12.9716), End: Madikeri (75.7394, 12.4306)
coordinates = [[77.5946, 12.9716], [75.7394, 12.4306]]  

# Make request to GraphHopper
params = {
    "point": [f"{lat},{lon}" for lon, lat in coordinates],  # convert to lat,lon strings
    "vehicle": "car",
    "points_encoded": False,
    "key": gh_key
}

response = requests.get(url, params=params)
if response.status_code == 200:
    print(" Route fetched successfully!")
    route_data = response.json()
    coordinates = route_data["paths"][0]["points"]["coordinates"]

    # Convert [lon, lat] → (lat, lon)
    decoded_points = [(lat, lon) for lon, lat in coordinates]
    print(f"Total route points: {len(decoded_points)}")

    # Sample 10 evenly spaced points from route
    sampled_points = [decoded_points[i] for i in np.linspace(0, len(decoded_points)-1, 10, dtype=int)]

    # Display sampled points
    for i, pt in enumerate(sampled_points):
        print(f" Point {i+1}: {pt}")

else:
    print(f" Failed to fetch route. Status Code: {response.status_code}")
    print("Raw Response:", response.text)
# Out:
#  Route fetched successfully!
# Total route points: 2582
#  Point 1: (12.971656, 77.594714)
#  Point 2: (12.887944, 77.48494)
#  Point 3: (12.739835, 77.290311)
#  Point 4: (12.568842, 77.003042)
#  Point 5: (12.436932, 76.711279)
#  Point 6: (12.355523, 76.523615)
#  Point 7: (12.338631, 76.19283)
#  Point 8: (12.445286, 75.926988)
#  Point 9: (12.436019, 75.80275)
#  Point 10: (12.430586, 75.739318)

# %%
encoded = route["routes"][0]["geometry"]
decoded_points = polyline.decode(encoded)
print(f"Total route points: {len(decoded_points)}")
# Out:
# Total route points: 2562

# %%
sampled_points = [decoded_points[i] for i in np.linspace(0, len(decoded_points)-1, 10, dtype=int)]
for i, pt in enumerate(sampled_points):
    print(f"Point {i+1}: {pt}")
# Out:
# Point 1: (12.97185, 77.5947)
# Point 2: (12.91002, 77.4812)
# Point 3: (12.73739, 77.24689)
# Point 4: (12.54619, 76.92915)
# Point 5: (12.35963, 76.66202)
# Point 6: (12.33478, 76.49222)
# Point 7: (12.32986, 76.20724)
# Point 8: (12.45748, 75.96035)
# Point 9: (12.43898, 75.80922)
# Point 10: (12.43059, 75.73932)

# %% [markdown]
# ## Get Weather Along Final Route

# %%
# Initialize geolocator
geolocator = Nominatim(user_agent="weather-playlist-planner")

# Function to fetch past weather using Open-Meteo
def get_weather(lat, lon, date="2024-05-24"):
    url = (
        "https://archive-api.open-meteo.com/v1/archive?"
        f"latitude={lat}&longitude={lon}&start_date={date}&end_date={date}"
        "&daily=temperature_2m_max,temperature_2m_min,uv_index_max,"
        "weathercode,precipitation_sum,wind_speed_10m_max"
        "&timezone=Asia%2FKolkata"
    )
    try:
        response = requests.get(url)
        response.raise_for_status()
        daily = response.json()["daily"]
        return {
            "Max Temp (°C)": daily["temperature_2m_max"][0],
            "Min Temp (°C)": daily["temperature_2m_min"][0],
            "Precipitation (mm)": daily["precipitation_sum"][0],
            "Wind (km/h)": daily["wind_speed_10m_max"][0],
            "UV Index": daily["uv_index_max"][0],
            "Weather Code": daily["weathercode"][0]
        }
    except Exception as e:
        print(f"Error fetching weather for ({lat}, {lon}):", e)
        return None

# Function to get location name using reverse geocoding
def reverse_geocode(lat, lon):
    try:
        location = geolocator.reverse((lat, lon), language='en')
        return location.address.split(",")[0]
    except:
        return "Unknown"

# Final list to build the DataFrame
weather_data = []

for idx, (lat, lon) in enumerate(sampled_points):
    print(f"Processing point {idx+1}/{len(sampled_points)}")

    weather = get_weather(lat, lon)
    location_name = reverse_geocode(lat, lon)

    if weather:
        row = {
            "Latitude": lat,
            "Longitude": lon,
            "Location": location_name
        }
        row.update(weather)
        weather_data.append(row)

    time.sleep(1)  # prevent hitting API rate limits

# Create DataFrame
df_weather_route = pd.DataFrame(weather_data)
print(" df_weather_route created!")
df_weather_route.head(10)
# Out:
# Processing point 1/10
# Processing point 2/10
# Processing point 3/10
# Processing point 4/10
# Processing point 5/10
# Processing point 6/10
# Processing point 7/10
# Processing point 8/10
# Processing point 9/10
# Processing point 10/10
#  df_weather_route created!
#     Latitude  Longitude                         Location  Max Temp (°C)  \
# 0  12.971656  77.594714  St. Joseph's Indian High School           29.8
# 1  12.887944  77.484940        NICE Peripheral Ring Road           31.1
# 2  12.739835  77.290311      Bengaluru-Mysuru Expressway           30.9
# 3  12.568842  77.003042      Bengaluru-Mysuru Expressway           31.8
# 4  12.436932  76.711279            Bangalore-Mysore Road           31.3
# 5  12.355523  76.523615                            NH275           29.3
# 6  12.338631  76.192830                            NH275           27.9
# 7  12.445286  75.926988                            NH275           28.3
# 8  12.436019  75.802750                      Mysore Road           25.3
# 9  12.430586  75.739318                 Ganapathi Street           23.8
#
#    Min Temp (°C)  Precipitation (mm)  Wind (km/h) UV Index  Weather Code
# 0           21.7                 3.5         16.0     None            55
# 1           22.4                 2.9         12.6     None            53
# 2           23.0                 7.1         16.8     None            63
# 3           23.3                10.4         12.9     None            63
# 4           22.7                 2.0         18.3     None            53
# 5           21.3                 3.7         16.3     None            55
# 6           20.8                 7.0         11.9     None            63
# 7           21.4                 4.4         17.3     None            61
# 8           20.0                 7.2         14.8     None            63
# 9           19.4                 6.4         13.2     None            63

# %% [markdown]
# ## Map Weather to Playlist Mood

# %%
mood_count = defaultdict(int)
used_queries = set()  # Tracks Spotify query strings already used

# Backup combos when all variations are exhausted
fallback_moods = [
    (" Fusion Drive", "Fusion Hindi Tamil"),
    (" Open Highway", "Hindi Roadtrip Classics"),
    (" Soulful Silence", "Minimal Ambient"),
    (" Retro Rewind", "Old Kannada"),
    (" Starry Chill", "English Lofi"),
    (" Melodic techno", "Electronic + Chillstep"),
    (" Calm Commute", "Instrumental Focus"),
]

def map_weather_to_playlist(temp, rain, wind, uv, location):
    try:
        if rain >= 10:
            base_mood = "Rainstorm Feels"
            base_query = "Arijit, Sid Sriram, Ambient"
        elif 6 <= rain < 10:
            base_mood = "Monsoon Romance"
            base_query = "Hindi + Tamil Lofi"
        elif 3 <= rain < 6 and temp <= 27:
            base_mood = "Cozy Moods"
            base_query = "Acoustic + Love Ballads"
        elif rain < 3 and temp > 30:
            base_mood = "Tropical Mood"
            base_query = "Bollywood Summer + Punjabi Beats"
        elif rain < 3 and temp >= 29 and wind < 12:
            base_mood = "Roadtrip Energy"
            base_query = "Hindi Pop + Tollywood Beats"
        elif wind >= 18:
            base_mood = "Chill Travel"
            base_query = "Hindi Chillstep, Lounge Jazz"
        elif temp < 24:
            base_mood = "Warmth & Melody"
            base_query = "Kannada, Tamil Piano, Soft Pop"
        else:
            base_mood = "Mixed Vibes"
            base_query = "Hindi Retro + English Classics"
    except:
        base_mood = "Unknown"
        base_query = "Relaxing Bollywood"

    # First full combination attempt
    base_combo = f"{base_mood} – {base_query}"
    if base_query not in used_queries:
        used_queries.add(base_query)
        return base_combo

    # Try alternative queries with same mood
    alt_queries = [
        "Kannada Classics",
        "Telugu Chill",
        "Indie Pop Vibes",
        "Soft Instrumentals",
        "English Vintage"
    ]
    for alt in alt_queries:
        if alt not in used_queries:
            used_queries.add(alt)
            return f"{base_mood} – {alt}"

    # Try fallback combinations
    for fallback_mood, fallback_query in fallback_moods:
        if fallback_query not in used_queries:
            used_queries.add(fallback_query)
            return f"{fallback_mood} – {fallback_query}"

    # Last resort: force unique name
    final_query = f"UNIQUE-{len(used_queries)}"
    used_queries.add(final_query)
    return f"{base_mood} – {final_query}"

# %%
df_weather_route["Playlist Mood"] = df_weather_route.apply(
    lambda row: map_weather_to_playlist(
        row["Max Temp (°C)"],
        row["Precipitation (mm)"],
        row["Wind (km/h)"],
        row["UV Index"] if row["UV Index"] is not None else 0,
        row["Location"]
    ),
    axis=1
)

# %%
pip install folium
# Out:
# Collecting foliumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\textmining\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in d:\textmining\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in d:\textmining\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\textmining\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\textmining\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\textmining\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\textmining\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\textmining\lib\site-packages (from requests->folium) (2024.12.14)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.1 folium-0.20.0 xyzservices-2025.4.0

# %% [markdown]
# ## Search Tracks Using Spotify API

# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-6.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.25.0 in d:\textmining\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in d:\textmining\lib\site-packages (from spotipy) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\textmining\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\textmining\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\textmining\lib\site-packages (from requests>=2.25.0->spotipy) (2024.12.14)
# Downloading spotipy-2.25.1-py3-none-any.whl (31 kB)
# Downloading redis-6.2.0-py3-none-any.whl (278 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-6.2.0 spotipy-2.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
def get_top_tracks_for_mood(mood_query, limit=25):
    try:
        results = sp.search(q=mood_query, type='playlist', limit=1)
        playlist_id = results['playlists']['items'][0]['id']

        tracks = sp.playlist_items(playlist_id, limit=limit)
        track_names = [
            f"{item['track']['name']} – {item['track']['artists'][0]['name']}"
            for item in tracks['items'] if item['track'] is not None
        ]
        return track_names
    except Exception as e:
        return [f"Error: {str(e)}"]

# %%
df_weather_route["Top Tracks"] = df_weather_route["Playlist Mood"].apply(
    lambda mood: get_top_tracks_for_mood(mood.split("–")[-1].strip())
)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %% [markdown]
# ## Compile Playlist for Each Route Point

# %%
playlist_entries = []
used_tracks = set()
track_cache = {}

for _, row in df_weather_route.iterrows():
    mood = row["Playlist Mood"]
    location = row["Location"]
    subqueries = mood.split("–")[-1].split(",")

    for subquery in subqueries:
        query = subquery.strip()

        # Cache search results
        if query not in track_cache:
            track_cache[query] = get_top_tracks_for_mood(query, limit=13)

        tracks = track_cache[query]
        print(f" Querying Spotify for: '{query}' at {location}")
        print(f"Tracks for query '{query}':\n", tracks)

        if not tracks or isinstance(tracks, str):
            print(f" No valid tracks returned for query: {query}")
            continue

        for track in tracks:
            try:
                name, artist = track.split(" – ")
                name, artist = name.strip(), artist.strip()
                track_id = (name, artist)  # unique identifier

                if track_id in used_tracks:
                    continue  # skip duplicates

                used_tracks.add(track_id)  # mark as used

                playlist_entries.append({
                    "Location": location,
                    "Mood": mood,
                    "Track Name": name,
                    "Artist": artist,
                    "Duration (min)": 3.5,
                    "Spotify Link": f"https://open.spotify.com/search/{name.replace(' ', '+')}"
                })

            except Exception as e:
                print(f" Skipping track due to error: {e}")
                continue

print(f"\n Total unique tracks collected: {len(playlist_entries)}")
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Hindi Retro + English Classics' at Vittal Mallya Road
# Tracks for query 'Hindi Retro + English Classics':
#  ['Aa Chal Ke Tujhe – Kishore Kumar', 'Aap Ki Nazron Ne Samjha – Lata Mangeshkar', 'Tere Mere Sapne Ab Ek Rang Hain – Mohammed Rafi', 'Abhi Na Jao Chhod Kar – Asha Bhosle', 'Tere Bina Zindagi Se (with Narration) – Lata Mangeshkar', 'Is Mod Se Jate Hain - Duet – Lata Mangeshkar', 'Tum Aa Gaye Ho Noor Aa Gaya – Lata Mangeshkar', 'Ek Ajnabee Haseena Se – Kishore Kumar', 'Bahon Mein Chale Aao – Lata Mangeshkar', 'Kahin Door Jab Din Dhal Jaye – Mukesh', 'Pal Pal Dil Ke Paas - From "Blackmail" – Kishore Kumar', 'Jab Deep Jale Aana – K. J. Yesudas', 'Aap Ki Ankhon Mein Kuch – Kishore Kumar']
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Bollywood Summer + Punjabi Beats' at Bangalore-Mysore Road
# Tracks for query 'Bollywood Summer + Punjabi Beats':
#  ['SHE IS STILL MY BABE – Romeo', 'Qayamat (From "Housefull 5") – White Noise Collectives', 'FEEL THE NIGHT – Romeo', 'Ikk Vaari - From "Mere Husband Ki Biwi" – Tanishk Bagchi', 'Sifarishan – Amar Emaan', 'Kissik (From "Pushpa 2 The Rule") [HINDI] – Lothika', 'Mafia – Harjas dhaliwal', 'Uyi Amma - From "Azaad" – Amit Trivedi', 'Djyaan Te Paaiye Bhangra – Armaan Sabharwal', 'Peelings (From "Pushpa 2 The Rule") [HINDI] – Javed Ali', 'Nain Matakka - From "Baby John" – Thaman S', 'Bhool Bhulaiyaa 3 - Title Track (feat. Pitbull) – Pitbull', "CHASIN' YOU – DANNY DIORR"]
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Hindi + Tamil Lofi' at Bengaluru-Mysuru Expressway
# Tracks for query 'Hindi + Tamil Lofi':
#  ['Mungaru Male x Lofi – Purohit Bhavya', 'Dior – PravZ', 'Mungaru Maleye – Sonu Nigam', 'Kannodu Kanbadhellam - Jeans Darloo Flip Mix – Darloo', 'Balwadi Rappers – SM Lucky', 'Athmave Poo - Swing Trap – Sushin Shyam', 'MAAYE #kannadalofi – DJ Lethal A', 'Katre En Vasal (Trap Mix) – Hemz', 'Get You The Moon / Agar Tum Saath Ho (Medley) – Pranish VP', 'THAMPU (kannadalofi) – DJ Lethal A', 'En Kannodu (Lofi Flip) – Narendar Sankar', 'En Iniya Pon Nilave - Remix – K. J. Yesudas', 'Neerabittu Nelada Mele - Lofi Flip – S. P. Balasubrahmanyam']
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Arijit' at Bengaluru-Mysuru Expressway
# Tracks for query 'Arijit':
#  ['Apna Bana Le – Sachin-Jigar', 'Zamaana Lage (From "Metro ... In Dino") – Pritam', 'Tujhe Kitna Chahne Lage (From "Kabir Singh") – Arijit Singh', 'Aur Mohabbat Kitni Karoon (From "Metro ... In Dino") – Pritam', 'Ve Kamleya (From "Rocky Aur Rani Kii Prem Kahaani") – Pritam', 'Dil Ka Kya (From "Metro ... In Dino") – Pritam', 'Hamari Adhuri Kahani (Title Track) – Jeet Gannguli', 'Mann Ye Mera (From "Metro ... In Dino") – Pritam', 'Tera Chehra – Himesh Reshammiya', 'Raatein Guzaari – Aditya Rikhari', 'Tera Fitoor – Arijit Singh', 'Mann Mera - Original Version – Gajendra Verma', 'Satranga (From "ANIMAL") – Arijit Singh']
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Sid Sriram' at Bengaluru-Mysuru Expressway
# Tracks for query 'Sid Sriram':
#  ["Error: 'NoneType' object is not subscriptable"]
#  Skipping track due to error: not enough values to unpack (expected 2, got 1)
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Ambient' at Bengaluru-Mysuru Expressway
# Tracks for query 'Ambient':
#  ['Rowan – Boreal Botany', 'Bioluminescence – oojoo', 'Leviathan Patera – Beth Null', 'Floating Ashore – Ookean', 'Tind – Drømmevind', 'Skies – Atmospheri', 'Starfield – So Lis', 'Cumulus – Humilis', 'Blunda – Broken Peak', 'Weightless – Center of Attention', 'Authentic – Spaced Out Dreams', 'Klippa – Dunsø', 'Peaceful Tides – Boundless Blue']
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
#  Querying Spotify for: 'Kannada Classics' at Bangalore - Mysore Expressway
# Tracks for query 'Kannada Classics':
#  ['Aa Devara Haadidu – Rajkumar', 'Aagumbeya Prema – Rajkumar', 'Aa Moda Bannalli – Rajkumar', 'Aaneya Mele – Rajkumar', 'Aaradhisuve Madanaari – Rajkumar', 'Aa Rathiye Dharegilidanthe – Rajkumar', 'Aasegala Lokadali – Rajkumar', 'Aaseu Kaigoodithu – Rajkumar', 'AATAVENO – Rajkumar', 'Adhey Kannu – Rajkumar', 'ADHYADHARA – Rajkumar', 'ALBYAD KANE – Rajkumar', 'ALLAH ALLAH NEENE YELLA – Rajkumar']
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'Telugu Chill' at NH275
# Tracks for query 'Telugu Chill':
#  ['Kalaavathi (From "Sarkaru Vaari Paata") – Sid Sriram', 'Sirivennela – Anurag Kulkarni', 'Ay Pilla - Telugu – Haricharan', 'So So Ga – Sid Sriram', 'Dosti (From "RRR") – Hemachandra Vedala', 'Kaatuka Kanule (From "Aakaasam Nee Haddhu Ra") – G. V. Prakash', 'Vastunna Vachestunna - Telugu – Shreya Ghoshal', ' – ', 'Manasa Manasa - Telugu – Sid Sriram', 'Neeli Neeli Aakasam (From "30 Rojullo Preminchadam Ela") – Sid Sriram', 'Tharagathi Gadhi - Telugu – Kala Bhairava', 'Pranam – Chinmayi Sripaada, Gowtham Bharadwaj V', 'Raletti – Divya S Menon']
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
#  Querying Spotify for: 'Indie Pop Vibes' at NH275
# Tracks for query 'Indie Pop Vibes':
#  ['One Kiss (with Dua Lipa) – Calvin Harris', 'Diet Pepsi – Addison Rae', 'Something Just Like This – The Chainsmokers', 'Outside (feat. Ellie Goulding) – Calvin Harris', 'Rock Your Body – Justin Timberlake', 'Summer – Calvin Harris', 'ANXIETY (feat. Doechii) – Sleepy Hallow', 'Time to Pretend – MGMT', 'BMF – SZA', 'OTW – Khalid', 'Electric Feel – MGMT', "Let's Groove – Earth, Wind & Fire", 'Get Lucky (feat. Pharrell Williams and Nile Rodgers) – Daft Punk']
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
#  Querying Spotify for: 'Soft Instrumentals' at NH275
# Tracks for query 'Soft Instrumentals':
#  ['deep love of Jesus - Instrumental – draw close', 'Redeemed – Khamir Music', 'pure – draw close', 'How Great Thou Art – Rasmus H Thomsen', 'Jesus We Love You – draw close', 'you are not alone – Khamir Music', 'My Savior – draw close', 'In Your Hands – Khamir Music', 'Yet - Instrumental – draw close', 'Gratitude (Peaceful Piano) – David Lindner', 'Abba - Instrumental – Christopher Galovan', 'meadows - Instrumental – Khamir Music', 'You found me - Instrumental – draw close']
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Querying Spotify for: 'English Vintage' at Mysore Road
# Tracks for query 'English Vintage':
#  ['A Sunday Kind Of Love – Etta James', "I'll Be Seeing You – Billie Holiday", 'Dream A Little Dream Of Me – Louis Armstrong', 'Misty - Live At Deutschlandhalle, Berlin, 1960 – Ella Fitzgerald', '(I Love You) For Sentimental Reasons – Nat King Cole', 'Blue Moon – Billie Holiday', 'I Fall In Love Too Easily – Chet Baker', "Somethin' Stupid – Frank Sinatra", 'Cheek To Cheek – Ella Fitzgerald', 'Everybody Loves Somebody – Dean Martin', 'L-O-V-E – Nat King Cole', 'More - Remastered 2004 – Bobby Darin', "I'm In The Mood For Love – Julie London"]
#  Querying Spotify for: 'Fusion Hindi Tamil' at Ganapathi Street
# Tracks for query 'Fusion Hindi Tamil':
#  ['Enthavo – Job Kurian', 'Mumbae Bounce – Sanjoy', 'N.R.I. – Raja Kumari', 'Vainko – Brodha V', 'Live It – SIRI', 'Ninna Guriya – MC Suhas', 'Namma Street – Tre Ess', ' – ', 'Meera – Raja Kumari', 'Mere Gully Mein (feat. Naezy) – DIVINE', 'Goriye – Desi Ma', 'Gold – SIRI', 'King-Don – Shaikhspeare']
#
#  Total unique tracks collected: 142

# %%
# Create map centered at start location
map_center = [df_weather_route["Latitude"].mean(), df_weather_route["Longitude"].mean()]
route_map = folium.Map(location=map_center, zoom_start=7)

# Add markers with mood info
marker_cluster = MarkerCluster().add_to(route_map)

for _, row in df_weather_route.iterrows():
    location = [row["Latitude"], row["Longitude"]]
    mood = row["Playlist Mood"]
    popup_info = f"""
    <b>{row['Location']}</b><br>
    Mood: {mood}<br>
    Max Temp: {row['Max Temp (°C)']}°C<br>
    Rain: {row['Precipitation (mm)']} mm<br>
    <a href="{row['Spotify Link']}" target="https://open.spotify.com/playlist/41KNDdhZ2yUZms9U5JqYXq">Spotify Search</a>
    """
    folium.Marker(location=location, popup=popup_info, icon=folium.Icon(color="blue")).add_to(marker_cluster)

route_map.save("interactive_route_map.html")
route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f4a3223567c33aeb99ed23d35c3b9d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f4a3223567c33aeb99ed23d35c3b9d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f4a3223567c33aeb99ed23d35c3b9d8 = L.map(
#                 &quot;map_8f4a3223567c33aeb99ed23d35c3b9d8&quot;,
#                 {
#                     center: [12.561125400000002, 76.62697870000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85e865e0f3fb9a733c5ad43f7b957f72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85e865e0f3fb9a733c5ad43f7b957f72.addTo(map_8f4a3223567c33aeb99ed23d35c3b9d8);
#
#
#             var marker_cluster_c6b6d3aae36f42addb43709ae125448f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a93daf6882786df6e96a281b63506b97 = L.marker(
#                 [12.971656, 77.594714],
#                 {
# }
#             ).addTo(marker_cluster_c6b6d3aae36f42addb43709ae125448f);
#
#
#             var icon_9d4dd1b88318092cfcb66efae40bfc2b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3cc66d81ef56c1e5485d613dfcdb3086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c374c53521d07822bdb3ec597251f92 = $(`&lt;div id=&quot;html_8c374c53521d07822bdb3ec597251f92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;St. Joseph&#x27;s Indian High School&lt;/b&gt;&lt;br&gt;     Mood:  Open Highway – Hindi Roadtrip Classics&lt;br&gt;     Max Temp: 29.8°C&lt;br&gt;     Rain: 3.5 mm&lt;br&gt;     &lt;a href=&quot;nan&quot; target=&quot;https://open.spotify.com/playlist/41KNDdhZ2yUZms9U5JqYXq&quot;&gt;Spotify Search&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_3cc66d81ef56c1e5485d613dfcdb3086.setContent(html_8c374c53521d07822bdb3ec597251f92);
#
#
#
#         marker_a93daf6882786df6e96a281b63506b97.bindPopup(popup_3cc66d81ef56c1e5485d613dfcdb3086)
#         ;
#
#
#
#
#                 marker_a93daf6882786df6e96a281b63506b97.setIcon(icon_9d4dd1b88318092cfcb66efae40bfc2b);
#
#
#             var marker_d073f80dadc2e47f646f8503a71ca22d = L.marker(
#                 [12.887944, 77.48494],
#                 {
# }
#             ).addTo(marker_cluster_c6b6d3aae36f42addb43709ae125448f);
#
#
#             var icon_edf222187171f455d73d33d85efe5174 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_729563266575e380a4851aedb83afe8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9afbc8fb661050eb8efd0a5f2ea78b96 = $(`&lt;div id=&quot;html_9afbc8fb661050eb8efd0a5f2ea78b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;NICE Peripheral Ring Road&lt;/b&gt;&lt;br&gt;     Mood:  Soulful Silence – Minimal Ambient&lt;br&gt;     Max Temp: 31.1°C&lt;br&gt;     Rain: 2.9 mm&lt;br&gt;     &lt;a href=&quot;nan&quot; target=&quot;https://open.spotify.com/playlist/41KNDdhZ2yUZms9U5JqYXq&quot;&gt;Spotify Search&lt;/a&gt;     &lt;/div&gt;`)[0];
#                 popup_729563266575e380a4851aedb83afe8d.setContent(html_9afbc8fb661050eb8efd0a5f2ea78b96);
#
#
#
#         marker_d073f80dadc2e47f646f8503a71ca22d.bindPopup(popup_729563266575e380a4851aedb83afe8d)
#         ;
#
#
#
#
#                 marker_d073f80dadc2e47f646f8503a71ca22d.setIcon(icon_edf222187171f455d73d33d85efe5174);
#
#
#             var marker_8a1096e05eb4284d6cd685fb60b97580 = L.marker(
#                 [12.73

# %% [markdown]
# ## Create Final Playlist

# %%
# Auth setup 
auth_manager = SpotifyOAuth(
    client_id="ENTER-YOUR-CLIENT-ID",
    client_secret="ENTER-YOUR-CLIENT-SECRET",
    redirect_uri="http://127.0.0.1:8888/callback",  # This must match Spotify Dashboard
    scope="playlist-modify-public",
    open_browser=True,
    show_dialog=True,
)

# Print the URL and manually authorize
auth_url = auth_manager.get_authorize_url()
print(f" Please go to this URL and authorize:\n{auth_url}")

# Paste the full redirect URL you get after login
redirect_response = input(" Paste the full redirect URL here:\n")

# Get token from code in that URL
code = auth_manager.parse_response_code(redirect_response)
token_info = auth_manager.get_access_token(code)

# Create Spotify client
sp = spotipy.Spotify(auth=token_info["access_token"])

# Verify
user = sp.current_user()
print(f" Authenticated as: {user['display_name']} (ID: {user['id']})")
# Out:
#  Please go to this URL and authorize:
# https://accounts.spotify.com/authorize?client_id=076219f7deb24b8c80f6d563a8d5f71f&response_type=code&redirect_uri=http%3A%2F%2F127.0.0.1%3A8888%2Fcallback&scope=playlist-modify-public&show_dialog=True
#  Paste the full redirect URL here:
#  http://127.0.0.1:8888/callback?code=AQAfJjc0KqXqKblSZScxJ_8jbGj5OO9PmKQpwx9goyhPMFbgfw3ifK8T2gjCwVExG8qma6_VKpp8xnyZLmmTzbPmX92FF9sbNG9eBHRILxcKVxFQpacydvMNwubG-3SBUugG5suROpJj-ZGwQyXGE2HFGfggm3cdon2e3AfFvKebWhOxC7pKuggMjojyi8nX_OfhGiQId5J5ng
# C:\Users\crpra\AppData\Local\Temp\ipykernel_14040\3902310482.py:23: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token_info = auth_manager.get_access_token(code)
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache
#  Authenticated as: Pranav (ID: 31phr65rgsk6ubzszhfwvbqlk7bu)

# %%
# Playlist name and description
playlist_name = f"Tunes for the Tarmac – 05/24/2025"
playlist_description = "A travel-inspired playlist generated by location and mood. Auto-curated by code"

# Create the playlist
playlist = sp.user_playlist_create(
    user=user['id'],
    name=playlist_name,
    public=True,
    description=playlist_description
)

print("Playlist created:", playlist['external_urls']['spotify'])
# Out:
# Playlist created: https://open.spotify.com/playlist/1A4AGa0MQ2CWqcfHObAwKs

# %%
track_uris_to_add = []

for entry in playlist_entries:
    query = f"track:{entry['Track Name']} artist:{entry['Artist']}"
    results = sp.search(q=query, type='track', limit=1)

    try:
        track_uri = results['tracks']['items'][0]['uri']
        track_uris_to_add.append(track_uri)
    except IndexError:
        print(f" Not found on Spotify: {entry['Track Name']} by {entry['Artist']}")

# Split into batches of 100 (Spotify’s limit)
for i in range(0, len(track_uris_to_add), 100):
    sp.playlist_add_items(playlist_id=playlist['id'], items=track_uris_to_add[i:i + 100])

print(f" Added {len(track_uris_to_add)} tracks to playlist.")
# Out:
#  Not found on Spotify: Is Mod Se Jate Hain - Duet by Lata Mangeshkar
#  Not found on Spotify: Kannodu Kanbadhellam - Jeans Darloo Flip Mix by Darloo
#  Not found on Spotify: Aaneya Mele by Rajkumar
#  Not found on Spotify: AATAVENO by Rajkumar
#  Not found on Spotify: Adhey Kannu by Rajkumar
#  Not found on Spotify: ALLAH ALLAH NEENE YELLA by Rajkumar
#  Not found on Spotify: Kalaavathi (From "Sarkaru Vaari Paata") by Sid Sriram
#  Added 135 tracks to playlist.

# %%
print("Your playlist is ready at:", playlist['external_urls']['spotify'])
# Out:
# Your playlist is ready at: https://open.spotify.com/playlist/1A4AGa0MQ2CWqcfHObAwKs

# %% [markdown]
# ## Generate Google Maps Route Link

# %%
locations = [
    "Vittal Mallya Road",
    "Mysore Rd, Bengaluru, Karnataka",
    "Bengaluru - Mysuru Expressway",
    "NH 275, Karnataka",
    "Madikeri"
]

# Convert each location into a URL-safe format
from urllib.parse import quote_plus

waypoints_encoded = [quote_plus(loc) for loc in locations]

# Join all points with '+' and insert into the Google Maps direction format
maps_url = f"https://www.google.com/maps/dir/{'/'.join(waypoints_encoded)}"

print("Google Maps Route Link:")
print(maps_url)
# Out:
# Google Maps Route Link:
# https://www.google.com/maps/dir/Vittal+Mallya+Road/Mysore+Rd%2C+Bengaluru%2C+Karnataka/Bengaluru+-+Mysuru+Expressway/NH+275%2C+Karnataka/Madikeri

# %%
route_coords = df_weather_route[["Latitude", "Longitude"]].values.tolist()

animated_map = folium.Map(location=map_center, zoom_start=7)
AntPath(route_coords, color="green", weight=5, delay=800).add_to(animated_map)

# Add start and end
folium.Marker(route_coords[0], tooltip="Start", icon=folium.Icon(color="green")).add_to(animated_map)
folium.Marker(route_coords[-1], tooltip="End", icon=folium.Icon(color="red")).add_to(animated_map)

animated_map.save("animated_route.html")
animated_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8397a162f8fe159d2779bbd908887b39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8397a162f8fe159d2779bbd908887b39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8397a162f8fe159d2779bbd908887b39 = L.map(
#                 &quot;map_8397a162f8fe159d2779bbd908887b39&quot;,
#                 {
#                     center: [12.561125400000002, 76.62697870000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c04746a805cd4eeb60d30462b865212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c04746a805cd4eeb60d30462b865212.addTo(map_8397a162f8fe159d2779bbd908887b39);
#
#
#             ant_path_7096972f07c66a89b8f663c7519dada5 = L.polyline.antPath(
#               [[12.971656, 77.594714], [12.887944, 77.48494], [12.739835, 77.290311], [12.568842, 77.003042], [12.436932, 76.711279], [12.355523, 76.523615], [12.338631, 76.19283], [12.445286, 75.926988], [12.436019, 75.80275], [12.430586, 75.739318]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;green&quot;,
#   &quot;weight&quot;: 5,
#   &quot;opacity&quot;: 0.5,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;green&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 800,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_8397a162f8fe159d2779bbd908887b39);
#
#
#             var marker_c98191d47a0333c8594d983a72285d49 = L.marker(
#                 [12.971656, 77.594714],
#                 {
# }
#             ).addTo(map_8397a162f8fe159d2779bbd908887b39);
#
#
#             var icon_3a730eb093aa28a70904f16b5ed74e2d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_c98191d47a0333c8594d983a72285d49.bindTooltip(
#                 `&lt;div&gt;
#                      Start
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c98191d47a0333c8594d983a72285d49.setIcon(icon_3a730eb093aa28a70904f16b5ed74e2d);
#
#
#             var marker_ba2c4ce9c13b3c52571db152f43e408f = L.marker(
#                 [12.430586, 75.739318],
#                 {
# }
#             ).addTo(map_8397a162f8fe159d2779bbd908887b39);
#
#
#             var icon_f59db496bb099f18524474f88bae9569 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#             marker_ba2c4ce9c13b3c52571db152f43e408f.bindTooltip(
#                 `&lt;div&gt;
#                      End
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ba2c4ce9c13b3c52571db152f43e408f.setIcon(icon_f59db496bb099f18524474f88bae9569);
#
#
#             tile_layer_1c04746a805cd4eeb60d30462b865212.addTo(map_8397a162f8fe159d2779bbd908887b39);
#
#
#                 marker_c98191d47a0333c8594d983a72285d49.setIcon(icon_3a730eb093aa28a70904f16b5ed74e2d);
#
#
#                 marker_ba2c4ce9c13b3c52571db152f43e408f.setIcon(icon_f59db496bb099f18524474f88bae9569);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
